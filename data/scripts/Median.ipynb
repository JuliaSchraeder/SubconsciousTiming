# %% [markdown]
# # Get median for:
#  - happy
#  - sad
#  - neutral
#  - conscious
#  - unconscious
#  - conscious happy/sad/neutral
#  - unconscious happy/sad/neutral

# %%
#import modules 
import pandas as pd
import ast, os
import numpy as np
import csv
import fileinput
import glob
import seaborn as sns
import statistics

# %% [markdown]
# ### Get data from study 1

# %%
# get name of participant to reconnect mean data with participant 
def name (participantcsv,vp_number):
    ID_1 =  participantcsv['participant'].tolist()
    ID = ID_1[0] 
    ID = ID[-3:]
    
    return ID

# %% [markdown]
# ### Get mean accuracy

# %%
def accuracy_unconscious(participantcsv, vp_number):
    accuracy_unconscious = statistics.median(unconscious['correct'].dropna())*100
    return accuracy_unconscious

def accuracy_conscious(participantcsv, vp_number):
    accuracy_conscious = statistics.median(conscious['correct'].dropna())*100
    return accuracy_conscious

def accuracy_happy(participantcsv, vp_number):
    accuracy_happy = statistics.median(happy['correct'].dropna())*100
    return accuracy_happy

def accuracy_sad(participantcsv, vp_number):
    accuracy_sad = statistics.median(sad['correct'].dropna())*100
    return accuracy_sad

def accuracy_neutral(participantcsv, vp_number):
    accuracy_neutral = statistics.median(neutral['correct'].dropna())*100
    return accuracy_neutral



def accuracy_unconscious_happy(participantcsv, vp_number):
    accuracy_unconscious_happy = statistics.median(unconscious_happy['correct'])*100
    return accuracy_unconscious_happy

def accuracy_unconscious_sad(participantcsv, vp_number):
    accuracy_unconscious_sad = statistics.median(unconscious_sad['correct'])*100
    return accuracy_unconscious_sad

def accuracy_unconscious_neutral(participantcsv, vp_number):
    accuracy_unconscious_neutral = statistics.median(unconscious_neutral['correct'])*100
    return accuracy_unconscious_neutral


def accuracy_conscious_happy(participantcsv, vp_number):
    accuracy_conscious_happy = statistics.median(conscious_happy['correct'])*100
    return accuracy_conscious_happy

def accuracy_conscious_sad(participantcsv, vp_number):
    accuracy_conscious_sad = statistics.median(conscious_sad['correct'])*100

    return accuracy_conscious_sad

def accuracy_conscious_neutral(participantcsv, vp_number):
    corr_ans = conscious_neutral['correct']
    # If len corr ans = Zero:
    if len(corr_ans) != 0:
        accuracy_conscious_neutral = statistics.median(conscious_neutral['correct'])*100
    else:
        accuracy_conscious_neutral = 0 
    return accuracy_conscious_neutral

# %% [markdown]
# ### Get mean rt

# %%
def rt_unconscious(participantcsv, vp_number):
    rt_unconscious = statistics.median(unconscious['key_resp_study.rt'].dropna())
    return rt_unconscious

def rt_conscious(participantcsv, vp_number):
    rt_conscious = statistics.median(conscious['key_resp_study.rt'].dropna())
    return rt_conscious

def rt_happy(participantcsv, vp_number):
    rt_happy = statistics.median(happy['key_resp_study.rt'].dropna())
    return rt_happy

def rt_sad(participantcsv, vp_number):
    rt_sad = statistics.median(sad['key_resp_study.rt'].dropna())
    return rt_sad

def rt_neutral(participantcsv, vp_number):
    rt_neutral = statistics.median(neutral['key_resp_study.rt'].dropna())
    return rt_neutral



def rt_unconscious_happy(participantcsv, vp_number):
    rt_unconscious_happy = statistics.median(unconscious_happy['key_resp_study.rt'])
    return rt_unconscious_happy

def rt_unconscious_sad(participantcsv, vp_number):
    rt_unconscious_sad = statistics.median(unconscious_sad['key_resp_study.rt'])
    return rt_unconscious_sad

def rt_unconscious_neutral(participantcsv, vp_number):
    rt_unconscious_neutral = statistics.median(unconscious_neutral['key_resp_study.rt'])
    return rt_unconscious_neutral


def rt_conscious_happy(participantcsv, vp_number):
    rt_conscious_happy = statistics.median(conscious_happy['key_resp_study.rt'])
    return rt_conscious_happy

def rt_conscious_sad(participantcsv, vp_number):
    rt_conscious_sad = statistics.median(conscious_sad['key_resp_study.rt'])

    return rt_conscious_sad

def rt_conscious_neutral(participantcsv, vp_number):
    corr_ans = conscious_neutral['key_resp_study.rt']
    # If len corr ans = Zero:
    if len(corr_ans) != 0:
        rt_conscious_neutral = statistics.median(conscious_neutral['key_resp_study.rt'])
    else:
        rt_conscious_neutral = 0 
    return rt_conscious_neutral

# %%
participant = glob.glob('.../data_behav/*.csv')

# %%
#create lists to append values and to store them in the dataframe df with mean reactions
list_accuracy_unconscious =[]
list_accuracy_conscious=[]

list_accuracy_happy =[]
list_accuracy_sad=[]
list_accuracy_neutral =[]

list_accuracy_unconscious_happy=[]
list_accuracy_unconscious_sad =[]
list_accuracy_unconscious_neutral=[]

list_accuracy_conscious_happy=[]
list_accuracy_conscious_sad =[]
list_accuracy_conscious_neutral =[]

participant_ID_list = []

# %%
list_rt_unconscious =[]
list_rt_conscious=[]

list_rt_happy =[]
list_rt_sad=[]
list_rt_neutral =[]

list_rt_unconscious_happy=[]
list_rt_unconscious_sad =[]
list_rt_unconscious_neutral=[]

list_rt_conscious_happy=[]
list_rt_conscious_sad =[]
list_rt_conscious_neutral =[]

# %%
for i in participant:
    #read in csv for every participant
    participantcsv = pd.read_csv(i, sep =",") #\t , ; ""
    
    #Delete 5 example trials
    participantcsv=participantcsv.drop([2,3,4,5,6])
    
    #get correct trials
    def correctness(participantcsv):
        if participantcsv['corrAnsPrimeStudy'] == participantcsv['key_resp_study.keys']:
            return 1
        else:
            return 0
    participantcsv['correct'] = participantcsv.apply(correctness, axis=1) 
    
    
    #Just get values smaller than 1.5
    participantcsv = participantcsv[(participantcsv['key_resp_study.rt'] <= 1.5)] 
    
    #Drop trials without reaction
    participantcsv = participantcsv.dropna(subset=['key_resp_study.rt'])

    #Get correct answers
    corr_answers = participantcsv['correct']
    reaction_time = participantcsv['key_resp_study.rt']

    #Create lists with trials per condition
    happy = participantcsv[(participantcsv['emotionPrimeStudy'] =='happy')]
    sad = participantcsv[(participantcsv['emotionPrimeStudy'] =='sad')]
    neutral = participantcsv[(participantcsv['emotionPrimeStudy'] =='neutral')]
    
    unconscious = participantcsv[(participantcsv['study mask time'] == 1) | (participantcsv['study mask time'] == 2) | (participantcsv['study mask time'] == 3)] 
    conscious = participantcsv[(participantcsv['study mask time'] == 17)] 
    
    unconscious_happy = unconscious[(unconscious['emotionPrimeStudy'] == 'happy')]
    unconscious_sad = unconscious[(unconscious['emotionPrimeStudy'] == 'sad')]
    unconscious_neutral = unconscious[(unconscious['emotionPrimeStudy'] == 'neutral')]
                                      
    conscious_happy = conscious[(conscious['emotionPrimeStudy'] == 'happy')]
    conscious_sad = conscious[(conscious['emotionPrimeStudy'] == 'sad')]
    conscious_neutral = conscious[(conscious['emotionPrimeStudy'] == 'neutral')]
    
    
    #Excecute functions and get one value for each participant
    #accuracy
    val_unconscious = accuracy_unconscious(participantcsv,i)
    val_conscious = accuracy_conscious(participantcsv,i)
    
    val_happy = accuracy_happy(participantcsv,i)
    val_sad = accuracy_sad(participantcsv,i)
    val_neutral = accuracy_neutral(participantcsv,i)                
                                    
    val_unconscious_happy = accuracy_unconscious_happy(participantcsv,i)
    val_unconscious_sad = accuracy_unconscious_sad(participantcsv,i)
    val_unconscious_neutral = accuracy_unconscious_neutral(participantcsv,i)
    
    val_conscious_happy = accuracy_conscious_happy(participantcsv,i)
    val_conscious_sad = accuracy_conscious_sad(participantcsv,i)
    val_conscious_neutral = accuracy_conscious_neutral(participantcsv,i)
    
    #rt
    val_rt_unconscious = rt_unconscious(participantcsv,i)
    val_rt_conscious = rt_conscious(participantcsv,i)

    val_rt_happy = rt_happy(participantcsv,i)
    val_rt_sad = rt_sad(participantcsv,i)
    val_rt_neutral = rt_neutral(participantcsv,i)                
                            
    val_rt_unconscious_happy = rt_unconscious_happy(participantcsv,i)
    val_rt_unconscious_sad = rt_unconscious_sad(participantcsv,i)
    val_rt_unconscious_neutral = rt_unconscious_neutral(participantcsv,i)

    val_rt_conscious_happy = rt_conscious_happy(participantcsv,i)
    val_rt_conscious_sad = rt_conscious_sad(participantcsv,i)
    val_rt_conscious_neutral = rt_conscious_neutral(participantcsv,i)
    
    participant_ID = name(participantcsv,i)

    
    #append values to append individual value to one list
                                    
    list_accuracy_unconscious.append(val_unconscious)
    list_accuracy_conscious.append(val_conscious)
    
    list_accuracy_happy.append(val_happy)
    list_accuracy_sad.append(val_sad)
    list_accuracy_neutral.append(val_neutral)
    
    list_accuracy_unconscious_happy.append(val_unconscious_happy)
    list_accuracy_unconscious_sad.append(val_unconscious_sad)
    list_accuracy_unconscious_neutral.append(val_unconscious_neutral)
    
    list_accuracy_conscious_happy.append(val_conscious_happy)
    list_accuracy_conscious_sad.append(val_conscious_sad)
    list_accuracy_conscious_neutral.append(val_conscious_neutral) 
    
    participant_ID_list.append(participant_ID)

    list_rt_unconscious.append(val_rt_unconscious)
    list_rt_conscious.append(val_rt_conscious)
    
    list_rt_happy.append(val_rt_happy)
    list_rt_sad.append(val_rt_sad)
    list_rt_neutral.append(val_rt_neutral)
    
    list_rt_unconscious_happy.append(val_rt_unconscious_happy)
    list_rt_unconscious_sad.append(val_rt_unconscious_sad)
    list_rt_unconscious_neutral.append(val_rt_unconscious_neutral)
    
    list_rt_conscious_happy.append(val_rt_conscious_happy)
    list_rt_conscious_sad.append(val_rt_conscious_sad)
    list_rt_conscious_neutral.append(val_rt_conscious_neutral) 
    
    study_number = 'study1'
    
    #Create dataframe 
    accuracy_data = {'name': participant_ID_list,
                     

                     
                     'rt happy':list_rt_happy,
                     'rt sad':list_rt_sad,
                     'rt neutral':list_rt_neutral,
                     'rt unconscious':list_rt_unconscious,
                     'rt conscious':list_rt_conscious,
                     
                     'rt unconscious happy':list_rt_unconscious_happy,
                     'rt unconscious sad':list_rt_unconscious_sad,
                     'rt unconscious neutral':list_rt_unconscious_neutral,
                     
                     'rt conscious happy':list_rt_conscious_happy,
                     'rt conscious sad':list_rt_conscious_sad,
                     'rt conscious neutral':list_rt_conscious_neutral,
                     
                    'study_number':study_number}
                                    
    mean_accuracy_1 = pd.DataFrame(data=accuracy_data).round(4)
    mean_accuracy_1['name'] = mean_accuracy_1['name'].replace(['0HZ'],'005')

# %%
mean_accuracy_1
# Out:
#    name  rt happy  rt sad  rt neutral  rt unconscious  rt conscious  \
# 0   009    0.4884  0.6772      0.5614          0.6425        0.4931
# 1   024    0.4830  0.5726      0.4939          0.5827        0.4377
# 2   003    0.6442  0.7994      0.8460          0.8804        0.6749
# 3   014    0.5364  0.6675      0.5342          0.7246        0.5178
# 4   022    0.7144  0.8805      0.8915          1.0502        0.6281
# 5   006    0.4434  0.5726      0.5242          0.5849        0.4347
# 6   002    0.5196  0.6786      0.6510          0.7070        0.4893
# 7   004    0.5191  0.7670      0.6564          0.8250        0.5152
# 8   008    0.4798  0.6254      0.5520          0.6913        0.4336
# 9   018    0.7723  0.8300      0.6919          0.7996        0.6866
# 10  015    0.4843  0.6315      0.7085          0.7378        0.5233
# 11  007    0.7338  0.9235      0.8591          0.9557        0.7586
# 12  020    0.5360  0.6953      0.7130          0.7738        0.5141
# 13  021    0.5498  0.6685      0.6803          0.7352        0.5192
# 14  001    0.5188  0.5697      0.5570          0.5978        0.4680
# 15  005    0.4613  0.6448      0.5716          0.8196        0.4268
# 16  010    0.5981  0.7921      0.7084          0.7884        0.5837
# 17  016    0.5902  0.6418      0.6653          0.6803        0.5863
# 18  017    0.4540  0.5148      0.5100          0.5758        0.4385
# 19  011    0.5478  0.6742      0.6100          0.7326        0.4863
#
#     rt unconscious happy  rt unconscious sad  rt unconscious neutral  \
# 0                 0.5939              0.7197                  0.6375
# 1                 0.5700              0.6091                  0.5771
# 2                 0.7512              0.9380                  0.9785
# 3                 0.6852              0.9926                  0.7494
# 4                 0.9101              1.1070                  1.0953
# 5                 0.5433              0.5993                  0.6205
# 6                 0.6308              0.7671                  0.7811
# 7                 0.7248              0.9325                  0.9300
# 8                 0.5648              0.7883                  0.7806
# 9                 0.8100              0.8300                  0.7806
# 10                0.6269              0.7542                  0.7944
# 11                0.9681              1.0223                  0.9045
# 12                0.6321              0.8880                  0.8278
# 13                0.6582              0.7946                  0.8014
# 14                0.6065              0.6163                  0.5787
# 15                0.6889              0.8872                  0.9071
# 16                0.6824              0.9017                  0.8480
# 17                0.6804              0.6739                  0.6950
# 18                0.5808              0.5687                  0.5758
# 19                0.6876              0.7648                  0.7023
#
#     rt conscious happy  rt conscious sad  rt conscious neutral study_number
# 0               0.3857            0.6425                0.4931       study1
# 1               0.4206            0.5063                0.4348       study1
# 2               0.5749            0.6774                0.7766       study1
# 3               0.4860            0.6080                0.5218       study1
# 4               0.5743            0.6619                0.7147       study1
# 5               0.3887            0.5370                0.4201       study1
# 6               0.4126            0.6362                0.4940       study1
# 7               0.4264            0.6440                0.5632       study1
# 8               0.3927            0.5317                0.4220       study1
# 9               0.6709            0.8355                0.6307       study1
# 10              0.4359            0.5873                0.6222       study1
# 11              0.5958            0.9186                0.7463       study1
# 12              0.4517            0.5419                0.5456       study1
# 13              0.4265            0.5688                0.5378       study1
# 14              0.4388            0.4663                0.5170       study1
# 15              0.3734            0.5406                0.4453       study1
# 16              0.5001            0.7341                0.5625       study1
# 17              0.4873            0.6248                0.6555       study1
# 18              0.3825            0.4901                0.4628       study1
# 19              0.4626            0.5070                0.5127       study1

# %%
mean_accuracy_1
# Out:
#    name  rt happy  rt sad  rt neutral  rt unconscious  rt conscious  \
# 0   009    0.4884  0.6772      0.5614          0.6425        0.4931
# 1   024    0.4830  0.5726      0.4939          0.5827        0.4377
# 2   003    0.6442  0.7994      0.8460          0.8804        0.6749
# 3   014    0.5364  0.6675      0.5342          0.7246        0.5178
# 4   022    0.7144  0.8805      0.8915          1.0502        0.6281
# 5   006    0.4434  0.5726      0.5242          0.5849        0.4347
# 6   002    0.5196  0.6786      0.6510          0.7070        0.4893
# 7   004    0.5191  0.7670      0.6564          0.8250        0.5152
# 8   008    0.4798  0.6254      0.5520          0.6913        0.4336
# 9   018    0.7723  0.8300      0.6919          0.7996        0.6866
# 10  015    0.4843  0.6315      0.7085          0.7378        0.5233
# 11  007    0.7338  0.9235      0.8591          0.9557        0.7586
# 12  020    0.5360  0.6953      0.7130          0.7738        0.5141
# 13  021    0.5498  0.6685      0.6803          0.7352        0.5192
# 14  001    0.5188  0.5697      0.5570          0.5978        0.4680
# 15  005    0.4613  0.6448      0.5716          0.8196        0.4268
# 16  010    0.5981  0.7921      0.7084          0.7884        0.5837
# 17  016    0.5902  0.6418      0.6653          0.6803        0.5863
# 18  017    0.4540  0.5148      0.5100          0.5758        0.4385
# 19  011    0.5478  0.6742      0.6100          0.7326        0.4863
#
#     rt unconscious happy  rt unconscious sad  rt unconscious neutral  \
# 0                 0.5939              0.7197                  0.6375
# 1                 0.5700              0.6091                  0.5771
# 2                 0.7512              0.9380                  0.9785
# 3                 0.6852              0.9926                  0.7494
# 4                 0.9101              1.1070                  1.0953
# 5                 0.5433              0.5993                  0.6205
# 6                 0.6308              0.7671                  0.7811
# 7                 0.7248              0.9325                  0.9300
# 8                 0.5648              0.7883                  0.7806
# 9                 0.8100              0.8300                  0.7806
# 10                0.6269              0.7542                  0.7944
# 11                0.9681              1.0223                  0.9045
# 12                0.6321              0.8880                  0.8278
# 13                0.6582              0.7946                  0.8014
# 14                0.6065              0.6163                  0.5787
# 15                0.6889              0.8872                  0.9071
# 16                0.6824              0.9017                  0.8480
# 17                0.6804              0.6739                  0.6950
# 18                0.5808              0.5687                  0.5758
# 19                0.6876              0.7648                  0.7023
#
#     rt conscious happy  rt conscious sad  rt conscious neutral study_number
# 0               0.3857            0.6425                0.4931       study1
# 1               0.4206            0.5063                0.4348       study1
# 2               0.5749            0.6774                0.7766       study1
# 3               0.4860            0.6080                0.5218       study1
# 4               0.5743            0.6619                0.7147       study1
# 5               0.3887            0.5370                0.4201       study1
# 6               0.4126            0.6362                0.4940       study1
# 7               0.4264            0.6440                0.5632       study1
# 8               0.3927            0.5317                0.4220       study1
# 9               0.6709            0.8355                0.6307       study1
# 10              0.4359            0.5873                0.6222       study1
# 11              0.5958            0.9186                0.7463       study1
# 12              0.4517            0.5419                0.5456       study1
# 13              0.4265            0.5688                0.5378       study1
# 14              0.4388            0.4663                0.5170       study1
# 15              0.3734            0.5406                0.4453       study1
# 16              0.5001            0.7341                0.5625       study1
# 17              0.4873            0.6248                0.6555       study1
# 18              0.3825            0.4901                0.4628       study1
# 19              0.4626            0.5070                0.5127       study1

# %% [markdown]
# # Study 2

# %%
def rt_unconscious(participantcsv, vp_number):
    rt_unconscious = statistics.median(unconscious['key_resp.rt'])
    return rt_unconscious

def rt_conscious(participantcsv, vp_number):
    rt_conscious = statistics.median(conscious['key_resp.rt'])
    return rt_conscious

def rt_happy(participantcsv, vp_number):
    rt_happy = statistics.median(happy['key_resp.rt'])
    return rt_happy

def rt_sad(participantcsv, vp_number):
    rt_sad = statistics.median(sad['key_resp.rt'])
    return rt_sad

def rt_neutral(participantcsv, vp_number):
    rt_neutral = statistics.median(neutral['key_resp.rt'])
    return rt_neutral



def rt_unconscious_happy(participantcsv, vp_number):
    rt_unconscious_happy = statistics.median(unconscious_happy['key_resp.rt'])
    return rt_unconscious_happy

def rt_unconscious_sad(participantcsv, vp_number):
    rt_unconscious_sad = statistics.median(unconscious_sad['key_resp.rt'])
    return rt_unconscious_sad

def rt_unconscious_neutral(participantcsv, vp_number):
    rt_unconscious_neutral = statistics.median(unconscious_neutral['key_resp.rt'])
    return rt_unconscious_neutral


def rt_conscious_happy(participantcsv, vp_number):
    rt_conscious_happy = statistics.median(conscious_happy['key_resp.rt'])
    return rt_conscious_happy

def rt_conscious_sad(participantcsv, vp_number):
    rt_conscious_sad = statistics.median(conscious_sad['key_resp.rt'])

    return rt_conscious_sad

def rt_conscious_neutral(participantcsv, vp_number):
    corr_ans = conscious_neutral['key_resp.rt']
    # If len corr ans = Zero:
    if len(corr_ans) != 0:
        rt_conscious_neutral = statistics.median(conscious_neutral['key_resp.rt'])
    else:
        rt_conscious_neutral = 0 
    return rt_conscious_neutral

# %%
participant = glob.glob('...data_behav_2/*.csv')

participant
# Out:
# ['/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot039_BackwardMask_2021_Dec_15_1153.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot041_BackwardMask_2022_Jan_07_1307.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot042_BackwardMask_2022_Jan_07_1403.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot045_BackwardMask_2022_Jan_07_1134.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot047_BackwardMask_2022_Jan_07_1536.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot030_BackwardMask_2021_Oct_20_1148.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot037_BackwardMask_2021_Nov_10_1338.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot028_BackwardMask_2021_Nov_24_1636.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot033_BackwardMask_2021_Nov_02_1523.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot027_BackwardMask_2021_Oct_27_1229.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot046_BackwardMask_2022_Jan_07_1217.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot043_BackwardMask_2022_Jan_07_1453.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot029_BackwardMask_2021_Nov_02_1439.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot038_BackwardMask_2021_Dec_01_1625.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot034_BackwardMask_2021_Dec_01_1718.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot025_BackwardMask_2021_Oct_19_1106.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot040_BackwardMask_2021_Dec_15_1247.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot048_BackwardMask_2022_Jan_19_1237.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot032_BackwardMask_2021_Oct_27_1337.csv',
#  '/Users/julia/Library/CloudStorage/OneDrive-UniklinikRWTHAachen/Auswertung/Pilot/data_behav_2/Emoconpilot036_BackwardMask_2021_Nov_10_1254.csv']

# %%
list_accuracy_unconscious =[]
list_accuracy_conscious=[]

list_accuracy_happy =[]
list_accuracy_sad=[]
list_accuracy_neutral =[]

list_accuracy_unconscious_happy=[]
list_accuracy_unconscious_sad =[]
list_accuracy_unconscious_neutral=[]

list_accuracy_conscious_happy=[]
list_accuracy_conscious_sad =[]
list_accuracy_conscious_neutral =[]

participant_ID_list = []

list_rt_unconscious =[]
list_rt_conscious=[]

list_rt_happy =[]
list_rt_sad=[]
list_rt_neutral =[]

list_rt_unconscious_happy=[]
list_rt_unconscious_sad =[]
list_rt_unconscious_neutral=[]

list_rt_conscious_happy=[]
list_rt_conscious_sad =[]
list_rt_conscious_neutral =[]

# %%
for i in participant:
    #read in csv for every participant
    participantcsv = pd.read_csv(i, sep =";") 
    
    #Delete 3 example trials
    participantcsv=participantcsv.drop([0,1,2])
    
    #get correct trials
    def correctness(participantcsv):
        if participantcsv['primeEmotion'] == "sad" and participantcsv['key_resp.keys']== "7":
            return 1
        if participantcsv['primeEmotion'] == "neutral" and participantcsv['key_resp.keys']== "8":
            return 1
        if participantcsv['primeEmotion'] == "happy" and participantcsv['key_resp.keys']== "9":
            return 1
        else:
            return 0
    participantcsv['correct'] = participantcsv.apply(correctness, axis=1)  
    
    
    #Just get values smaller than 1.5
    participantcsv = participantcsv[(participantcsv['key_resp.rt'] <= 1.5)] 
    #Drop trials without reaction
    participantcsv = participantcsv.dropna(subset=['key_resp.rt'])

    #Get correct answers
    corr_answers = participantcsv['correct']
    reaction_time = participantcsv['key_resp.rt']

    #Create lists with trials per condition
    happy = participantcsv[(participantcsv['primeEmotion'] =='happy')]
    sad = participantcsv[(participantcsv['primeEmotion'] =='sad')]
    neutral = participantcsv[(participantcsv['primeEmotion'] =='neutral')]
    
    unconscious = participantcsv[(participantcsv['PrimerTime120'] == 1) | (participantcsv['PrimerTime120'] == 2) | (participantcsv['PrimerTime120'] == 3)] 
    conscious = participantcsv[(participantcsv['PrimerTime120'] == 18)] 
    
    unconscious_happy = unconscious[(unconscious['primeEmotion'] == 'happy')]
    unconscious_sad = unconscious[(unconscious['primeEmotion'] == 'sad')]
    unconscious_neutral = unconscious[(unconscious['primeEmotion'] == 'neutral')]
                                      
    conscious_happy = conscious[(conscious['primeEmotion'] == 'happy')]
    conscious_sad = conscious[(conscious['primeEmotion'] == 'sad')]
    conscious_neutral = conscious[(conscious['primeEmotion'] == 'neutral')]
    
    
    #Excecute functions and get one value for each participant
    #accuracy
    val_unconscious = accuracy_unconscious(participantcsv,i)
    val_conscious = accuracy_conscious(participantcsv,i)
    
    val_happy = accuracy_happy(participantcsv,i)
    val_sad = accuracy_sad(participantcsv,i)
    val_neutral = accuracy_neutral(participantcsv,i)                
                                    
    val_unconscious_happy = accuracy_unconscious_happy(participantcsv,i)
    val_unconscious_sad = accuracy_unconscious_sad(participantcsv,i)
    val_unconscious_neutral = accuracy_unconscious_neutral(participantcsv,i)
    
    val_conscious_happy = accuracy_conscious_happy(participantcsv,i)
    val_conscious_sad = accuracy_conscious_sad(participantcsv,i)
    val_conscious_neutral = accuracy_conscious_neutral(participantcsv,i)
    
    #rt
    val_rt_unconscious = rt_unconscious(participantcsv,i)
    val_rt_conscious = rt_conscious(participantcsv,i)

    val_rt_happy = rt_happy(participantcsv,i)
    val_rt_sad = rt_sad(participantcsv,i)
    val_rt_neutral = rt_neutral(participantcsv,i)                
                            
    val_rt_unconscious_happy = rt_unconscious_happy(participantcsv,i)
    val_rt_unconscious_sad = rt_unconscious_sad(participantcsv,i)
    val_rt_unconscious_neutral = rt_unconscious_neutral(participantcsv,i)

    val_rt_conscious_happy = rt_conscious_happy(participantcsv,i)
    val_rt_conscious_sad = rt_conscious_sad(participantcsv,i)
    val_rt_conscious_neutral = rt_conscious_neutral(participantcsv,i)
    
    participant_ID = name(participantcsv,i)

    
    #append values to append individual value to one list
                                    
    list_accuracy_unconscious.append(val_unconscious)
    list_accuracy_conscious.append(val_conscious)
    
    list_accuracy_happy.append(val_happy)
    list_accuracy_sad.append(val_sad)
    list_accuracy_neutral.append(val_neutral)
    
    list_accuracy_unconscious_happy.append(val_unconscious_happy)
    list_accuracy_unconscious_sad.append(val_unconscious_sad)
    list_accuracy_unconscious_neutral.append(val_unconscious_neutral)
    
    list_accuracy_conscious_happy.append(val_conscious_happy)
    list_accuracy_conscious_sad.append(val_conscious_sad)
    list_accuracy_conscious_neutral.append(val_conscious_neutral) 
    
    participant_ID_list.append(participant_ID)

    list_rt_unconscious.append(val_rt_unconscious)
    list_rt_conscious.append(val_rt_conscious)
    
    list_rt_happy.append(val_rt_happy)
    list_rt_sad.append(val_rt_sad)
    list_rt_neutral.append(val_rt_neutral)
    
    list_rt_unconscious_happy.append(val_rt_unconscious_happy)
    list_rt_unconscious_sad.append(val_rt_unconscious_sad)
    list_rt_unconscious_neutral.append(val_rt_unconscious_neutral)
    
    list_rt_conscious_happy.append(val_rt_conscious_happy)
    list_rt_conscious_sad.append(val_rt_conscious_sad)
    list_rt_conscious_neutral.append(val_rt_conscious_neutral) 
    
    study_number = 'study2'
    
    #Create dataframe 
    accuracy_data = {'name': participant_ID_list,
                     

                     
                     'rt happy':list_rt_happy,
                     'rt sad':list_rt_sad,
                     'rt neutral':list_rt_neutral,
                     'rt unconscious':list_rt_unconscious,
                     'rt conscious':list_rt_conscious,
                     
                     'rt unconscious happy':list_rt_unconscious_happy,
                     'rt unconscious sad':list_rt_unconscious_sad,
                     'rt unconscious neutral':list_rt_unconscious_neutral,
                     
                     'rt conscious happy':list_rt_conscious_happy,
                     'rt conscious sad':list_rt_conscious_sad,
                     'rt conscious neutral':list_rt_conscious_neutral,
                     
                    'study_number':study_number}
                                    
    mean_accuracy_2 = pd.DataFrame(data=accuracy_data).round(4)

# %%
frames = [mean_accuracy_1, mean_accuracy_2]
result = pd.concat(frames)
result
# Out:
#    name  rt happy  rt sad  rt neutral  rt unconscious  rt conscious  \
# 0   009    0.4884  0.6772      0.5614          0.6425        0.4931
# 1   024    0.4830  0.5726      0.4939          0.5827        0.4377
# 2   003    0.6442  0.7994      0.8460          0.8804        0.6749
# 3   014    0.5364  0.6675      0.5342          0.7246        0.5178
# 4   022    0.7144  0.8805      0.8915          1.0502        0.6281
# 5   006    0.4434  0.5726      0.5242          0.5849        0.4347
# 6   002    0.5196  0.6786      0.6510          0.7070        0.4893
# 7   004    0.5191  0.7670      0.6564          0.8250        0.5152
# 8   008    0.4798  0.6254      0.5520          0.6913        0.4336
# 9   018    0.7723  0.8300      0.6919          0.7996        0.6866
# 10  015    0.4843  0.6315      0.7085          0.7378        0.5233
# 11  007    0.7338  0.9235      0.8591          0.9557        0.7586
# 12  020    0.5360  0.6953      0.7130          0.7738        0.5141
# 13  021    0.5498  0.6685      0.6803          0.7352        0.5192
# 14  001    0.5188  0.5697      0.5570          0.5978        0.4680
# 15  005    0.4613  0.6448      0.5716          0.8196        0.4268
# 16  010    0.5981  0.7921      0.7084          0.7884        0.5837
# 17  016    0.5902  0.6418      0.6653          0.6803        0.5863
# 18  017    0.4540  0.5148      0.5100          0.5758        0.4385
# 19  011    0.5478  0.6742      0.6100          0.7326        0.4863
# 0   039    0.8084  0.9551      0.7367          0.8571        0.6930
# 1   041    0.8588  0.9834      0.7916          0.8994        0.8112
# 2   042    1.0433  1.0822      0.8977          0.9855        1.0578
# 3   045    0.5420  0.7258      0.6241          0.6620        0.4944
# 4   047    0.5509  0.7000      0.6101          0.6579        0.4799
# 5   030    0.5970  0.7537      0.7017          0.7347        0.5715
# 6   037    0.5255  0.6153      0.5494          0.5910        0.4397
# 7   028    0.5820  0.7310      0.5701          0.6207        0.5481
# 8   033    0.5107  0.6584      0.5739          0.6374        0.4528
# 9   027    0.6857  0.8731      0.9002          0.8819        0.7195
# 10  046    0.5011  0.6507      0.6097          0.6437        0.4818
# 11  043    0.7776  0.9738      0.8106          0.8852        0.7472
# 12  029    0.6920  0.8479      0.7751          0.8351        0.5761
# 13  038    0.5416  0.6735      0.5812          0.6080        0.5027
# 14  034    0.7224  0.8603      0.6833          0.8258        0.5846
# 15  025    0.7331  0.8745      0.7446          0.7951        0.7336
# 16  040    0.7881  0.9486      0.9195          0.9236        0.8079
# 17  048    0.7937  0.9163      0.8446          0.9007        0.7580
# 18  032    0.5773  0.7186      0.6066          0.6738        0.5165
# 19  036    0.5143  0.7358      0.5310          0.6085        0.4660
#
#     rt unconscious happy  rt unconscious sad  rt unconscious neutral  \
# 0                 0.5939              0.7197                  0.6375
# 1                 0.5700              0.6091                  0.5771
# 2                 0.7512              0.9380                  0.9785
# 3                 0.6852              0.9926                  0.7494
# 4                 0.9101              1.1070                  1.0953
# 5                 0.5433              0.5993                  0.6205
# 6                 0.6308              0.7671                  0.7811
# 7                 0.7248              0.9325                  0.9300
# 8                 0.5648              0.7883                  0.7806
# 9                 0.8100              0.8300                  0.7806
# 10                0.6269              0.7542                  0.7944
# 11                0.9681              1.0223                  0.9045
# 12                0.6321              0.8880                  0.8278
# 13                0.6582              0.7946                  0.8014
# 14                0.6065              0.6163                  0.5787
# 15                0.6889              0.8872                  0.9071
# 16                0.6824              0.9017                  0.8480
# 17                0.6804              0.6739                  0.6950
# 18                0.5808              0.5687                  0.5758
# 19                0.6876              0.7648                  0.7023
# 0                 0.8550              1.0361                  0.7557
# 1                 0.8838              1.0259                  0.8388
# 2                 0.9545              1.0817                  0.9410
# 3                 0.5739              0.7632                  0.6860
# 4                 0.5866              0.7544                  0.6781
# 5                 0.6143              0.7907                  0.7492
# 6                 0.5623              0.6750                  0.5934
# 7                 0.6138              0.7918                  0.5797
# 8                 0.5290              0.7094                  0.6374
# 9                 0.7398              1.0078                  0.9527
# 10                0.5212              0.6944                  0.6635
# 11                0.7971              1.0777                  0.8785
# 12                0.7405              0.9516                  0.8810
# 13                0.5725              0.7112                  0.5988
# 14                0.7486              0.9522                  0.8248
# 15                0.7252              0.9679                  0.8253
# 16                0.8208              1.0280                  1.0005
# 17                0.8679              0.9703                  0.9091
# 18                0.6248              0.7551                  0.6755
# 19                0.5480              0.7766                  0.6122
#
#     rt conscious happy  rt conscious sad  rt conscious neutral study_number
# 0               0.3857            0.6425                0.4931       study1
# 1               0.4206            0.5063                0.4348       study1
# 2               0.5749            0.6774                0.7766       study1
# 3               0.4860            0.6080                0.5218       study1
# 4               0.5743            0.6619                0.7147       study1
# 5               0.3887            0.5370                0.4201       study1
# 6               0.4126            0.6362                0.4940       study1
# 7               0.4264            0.6440                0.5632       study1
# 8               0.3927            0.5317                0.4220       study1
# 9               0.6709            0.8355                0.6307       study1
# 10              0.4359            0.5873                0.6222       study1
# 11              0.5958            0.9186                0.7463       study1
# 12              0.4517            0.5419                0.5456       study1
# 13              0.4265            0.5688                0.5378       study1
# 14              0.4388            0.4663                0.5170       study1
# 15              0.3734            0.5406                0.4453       study1
# 16              0.5001            0.7341                0.5625       study1
# 17              0.4873            0.6248                0.6555       study1
# 18              0.3825            0.4901                0.4628       study1
# 19              0.4626            0.5070                0.5127       study1
# 0               0.6706            0.8252                0.6224       study2
# 1               0.7131            0.9541                0.7007       study2
# 2               1.1665            1.0915                0.8759       study2
# 3               0.3787            0.6646                0.4899       study2
# 4               0.4404            0.5560                0.4749       study2
# 5               0.4305            0.6428                0.5715       study2
# 6               0.3682            0.5624                0.4060       study2
# 7               0.4600            0.6561                0.5348       study2
# 8               0.3734            0.5206                0.4284       study2
# 9               0.6194            0.7278                0.7720       study2
# 10              0.3711            0.5166                0.5072       study2
# 11              0.6559            0.8821                0.6954       study2
# 12              0.4861            0.6278                0.5621       study2
# 13              0.4045            0.5742                0.4836       study2
# 14              0.5613            0.7128                0.4680       study2
# 15              0.7662            0.8066                0.6041       study2
# 16              0.6326            0.9000                0.7914       study2
# 17              0.7128            0.8702                0.6917       study2
# 18              0.4316            0.6542                0.4831       study2
# 19              0.3807            0.6713                0.4267       study2

# %%
result.to_csv(r'.../Median.csv',sep =';', index = True)     


result.to_excel("Median.xlsx",sheet_name='Sheet_name_1')
