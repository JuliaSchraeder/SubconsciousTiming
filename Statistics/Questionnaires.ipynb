# %%
import pandas as pd
import pingouin as pg
from pingouin import ttest

# %%
data = pd.read_excel('C:/Users/juhoffmann/OneDrive - Uniklinik RWTH Aachen/Auswertung/Pilot2/Questionnaires/Auswertung_Pilotstudie_Neu_Short.xlsx')

# %%
data
# Out:
#             SERIAL  Age  Gender Sex  ScoreBDI  ScoreBVAQ_B  TMT_A  \
# 0   EMOCONPILOT001   28       2   m         0           56   23.5
# 1   EMOCONPILOT002   30       1   f         0           59   18.5
# 2   EMOCONPILOT003   30       1   f         0           56   47.0
# 3   EMOCONPILOT004   30       1   f         0           55   29.5
# 4   EMOCONPILOT005   27       2   m         1           58   17.0
# 5   EMOCONPILOT006   29       1   f         1           53   18.0
# 6   EMOCONPILOT007   28       2   m         0           50   28.5
# 7   EMOCONPILOT008   23       1   f         1           55   24.0
# 8   EMOCONPILOT009   21       1   f         7           56   20.0
# 9   EMOCONPILOT010   30       2   m         0           54   26.0
# 10  EMOCONPILOT011   24       1   f         8           64   24.0
# 11  EMOCONPILOT014   29       1   f        14           62   25.0
# 12  EMOCONPILOT015   26       2   m         0           56   25.0
# ...

# %%
desc_stat=data.describe()
desc_stat.to_csv('C:/Users/juhoffmann/OneDrive - Uniklinik RWTH Aachen/Auswertung/Pilot2/Questionnaires/Descriptive_stat_Questionnaire.csv',sep =';', index = True)

# %%
male = data[(data['Sex'] == "m")] 
female = data[(data['Sex'] == "f")] 
acc_male = male['accuracy']
acc_female = female['accuracy']
rt_male = male['mean_reaction_time']
rt_female = female['mean_reaction_time']

# %%
pg.normality(acc_male).round(3)
# Out:
#              W   pval  normal
# accuracy  0.85  0.095    True

# %%
pg.normality(acc_female).round(3)
# Out:
#               W   pval  normal
# accuracy  0.948  0.613    True

# %%
ttest(acc_male,acc_female)
# Out:
#                T        dof       tail     p-val          CI95%   cohen-d  \
# T-test  2.107269  17.931251  two-sided  0.049438  [0.02, 12.73]  0.893367
#
#          BF10     power
# T-test  1.718  0.457333

# %%
pg.normality(rt_male).round(3)
# Out:
#                         W   pval  normal
# mean_reaction_time  0.933  0.544    True

# %%
pg.normality(rt_female).round(3)
# Out:
#                         W   pval  normal
# mean_reaction_time  0.944  0.547    True

# %%
ttest(rt_male,rt_female)
# Out:
#                T       dof       tail     p-val          CI95%   cohen-d  \
# T-test  1.208579  11.87386  two-sided  0.250343  [-0.05, 0.16]  0.588823
#
#          BF10     power
# T-test  0.665  0.230954
