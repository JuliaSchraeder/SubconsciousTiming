# %%
#import modules 
import pandas as pd
import ast, os
import numpy as np
import csv
import fileinput
import glob
import seaborn as sns

# %%
#how many answere where correct? in total
def numbercorrans(participantcsv, vp_number):                        
    number_corr_ans_nonformatted = sum(corr_answers) 
    number_corr_ans = "{:.0f}".format(number_corr_ans_nonformatted) # format value to not show .0
    
    return number_corr_ans

# %%
#How often was a key pressed?
def reactionnumber(participantcsv, vp_number):
    reaction_number = len(reaction_time)                          # number of reactions without missing values
    
    return reaction_number

# %%
def reactiontotal(participantcsv, vp_number):
    reactionTime_total = participantcsv['key_resp_study.rt']
    df_all_reactions['total'] = reactionTime_total
    return reactionTime_total

# %%
# reactionTime

#8ms
def reactionTime_uncon_8ms_happy(participantcsv, vp_number):
    reactionTime_uncon_8ms_happy = uncon_8ms_happy['key_resp_study.rt']
    df_all_reactions['uncon_8ms_happy'] = reactionTime_uncon_8ms_happy 
    return reactionTime_uncon_8ms_happy

def reactionTime_uncon_8ms_sad(participantcsv, vp_number):
    reactionTime_uncon_8ms_sad = uncon_8ms_sad['key_resp_study.rt']
    df_all_reactions['uncon_8ms_sad'] = reactionTime_uncon_8ms_sad 
    return reactionTime_uncon_8ms_sad

def reactionTime_uncon_8ms_neutral(participantcsv, vp_number):
    reactionTime_uncon_8ms_neutral = uncon_8ms_neutral['key_resp_study.rt']
    df_all_reactions['uncon_8ms_neutral'] = reactionTime_uncon_8ms_neutral 
    return reactionTime_uncon_8ms_neutral


#16ms
def reactionTime_uncon_16ms_happy(participantcsv, vp_number):
    reactionTime_uncon_16ms_happy = uncon_16ms_happy['key_resp_study.rt']
    df_all_reactions['uncon_16ms_happy'] = reactionTime_uncon_16ms_happy 
    return reactionTime_uncon_16ms_happy

def reactionTime_uncon_16ms_sad(participantcsv, vp_number):
    reactionTime_uncon_16ms_sad = uncon_16ms_sad['key_resp_study.rt']
    df_all_reactions['uncon_16ms_sad'] = reactionTime_uncon_16ms_sad 
    return reactionTime_uncon_16ms_sad

def reactionTime_uncon_16ms_neutral(participantcsv, vp_number):
    reactionTime_uncon_16ms_neutral = uncon_16ms_neutral['key_resp_study.rt']
    df_all_reactions['uncon_16ms_neutral'] = reactionTime_uncon_16ms_neutral 
    return reactionTime_uncon_16ms_neutral


#25ms
def reactionTime_uncon_25ms_happy(participantcsv, vp_number):
    reactionTime_uncon_25ms_happy = uncon_25ms_happy['key_resp_study.rt']
    df_all_reactions['uncon_25ms_happy'] = reactionTime_uncon_25ms_happy 
    return reactionTime_uncon_25ms_happy

def reactionTime_uncon_25ms_sad(participantcsv, vp_number):
    reactionTime_uncon_25ms_sad = uncon_25ms_sad['key_resp_study.rt']
    df_all_reactions['uncon_25ms_sad'] = reactionTime_uncon_25ms_sad 
    return reactionTime_uncon_25ms_sad

def reactionTime_uncon_25ms_neutral(participantcsv, vp_number):
    reactionTime_uncon_25ms_neutral = uncon_25ms_neutral['key_resp_study.rt']
    df_all_reactions['uncon_25ms_neutral'] = reactionTime_uncon_25ms_neutral 
    return reactionTime_uncon_25ms_neutral

#141ms
def reactionTime_con_141ms_happy(participantcsv, vp_number):
    reactionTime_con_141ms_happy = con_141ms_happy['key_resp_study.rt']
    df_all_reactions['con_141ms_happy'] = reactionTime_con_141ms_happy 
    return reactionTime_con_141ms_happy

def reactionTime_con_141ms_sad(participantcsv, vp_number):
    reactionTime_con_141ms_sad = con_141ms_sad['key_resp_study.rt']
    df_all_reactions['con_141ms_sad'] = reactionTime_con_141ms_sad 
    return reactionTime_con_141ms_sad

def reactionTime_con_141ms_neutral(participantcsv, vp_number):
    reactionTime_con_141ms_neutral = con_141ms_neutral['key_resp_study.rt']
    df_all_reactions['con_141ms_neutral'] = reactionTime_con_141ms_neutral 
    return reactionTime_con_141ms_neutral

# %%
# get name of participant to reconnect mean data with participant 
def name (participantcsv,vp_number):
    ID_1 =  participantcsv['participant'].tolist()
    ID = ID_1[0] 
    df_all_reactions['ID'] = ID
    
    return ID

# %%
#def conditions(participantcsv):
#    if (participantcsv['study mask time'] == 1) and (participantcsv['emotionPrimeStudy'] == 'happy'):
#        return "8ms_happy"
#    elif (participantcsv['study mask time'] == 1) and (participantcsv['emotionPrimeStudy'] == 'sad'):
#        return "8ms_sad"
#    elif (participantcsv['study mask time'] == 1) and (participantcsv['emotionPrimeStudy'] == 'neutral'):
#        return "8ms_neutral"        
#       
#    elif (participantcsv['study mask time'] == 2) and (participantcsv['emotionPrimeStudy'] == 'happy'):
#        return "16ms_happy"
#    elif (participantcsv['study mask time'] == 2) and (participantcsv['emotionPrimeStudy'] == 'sad'):
#        return "16ms_sad"
#    elif (participantcsv['study mask time'] == 2) and (participantcsv['emotionPrimeStudy'] == 'neutral'):
#        return "16ms_neutral"      
#    
#    elif (participantcsv['study mask time'] == 3) and (participantcsv['emotionPrimeStudy'] == 'happy'):
#        return "25ms_happy"
#    elif (participantcsv['study mask time'] == 3) and (participantcsv['emotionPrimeStudy'] == 'sad'):
#        return "25ms_sad"
#    elif (participantcsv['study mask time'] == 3) and (participantcsv['emotionPrimeStudy'] == 'neutral'):
#        return "25ms_neutral"           
#    
#    elif (participantcsv['study mask time'] == 17) and (participantcsv['emotionPrimeStudy'] == 'happy'):
#        return "141ms_happy"
#    elif (participantcsv['study mask time'] == 17) and (participantcsv['emotionPrimeStudy'] == 'sad'):
#        return "141ms_sad"
#    elif (participantcsv['study mask time'] == 17) and (participantcsv['emotionPrimeStudy'] == 'neutral'):
#        return "141ms_neutral"              
#    else:
#        return 0
#
#

# %%
#Need this to create List of all reactions (seperated in happy, sad, neutral, and different
# primers for every participant
trials = [*range(1,369)] #360 trials + 9 possible practice trials, each list is 360 items long
# Define a dictionary containing Students data 
data = {'': trials}    
# Convert the dictionary into DataFrame 
df_all_reactions = pd.DataFrame(data)

# %%
#read in csv data generated by PsychoPy
participant = glob.glob('C:/Users/juhoffmann/OneDrive - Uniklinik RWTH Aachen/Auswertung/Pilot2/data_behav/*.csv') 
#participant = glob.glob('/Users/julia/OneDrive - Uniklinik RWTH Aachen/Auswertung/Pilot2/data_behav/*.csv') 


#test if this had work
#participant

# %%
for i in participant:
    #read in csv for every participant
    participantcsv = pd.read_csv(i, sep =",") #\t , ; ""
    #insert index of trials for study part (exclude example trials with -6)
    length = len(participantcsv)-6
    participantcsv.insert(loc=0, column='index', value=np.arange(-6,length))
    
    
    def conditions(participantcsv):
        if (participantcsv['study mask time'] == 1) and (participantcsv['emotionPrimeStudy'] == 'happy'):
            return "8ms_happy"
        elif (participantcsv['study mask time'] == 1) and (participantcsv['emotionPrimeStudy'] == 'sad'):
            return "8ms_sad"
        elif (participantcsv['study mask time'] == 1) and (participantcsv['emotionPrimeStudy'] == 'neutral'):
            return "8ms_neutral"        
           
        elif (participantcsv['study mask time'] == 2) and (participantcsv['emotionPrimeStudy'] == 'happy'):
            return "16ms_happy"
        elif (participantcsv['study mask time'] == 2) and (participantcsv['emotionPrimeStudy'] == 'sad'):
            return "16ms_sad"
        elif (participantcsv['study mask time'] == 2) and (participantcsv['emotionPrimeStudy'] == 'neutral'):
            return "16ms_neutral"      
        
        elif (participantcsv['study mask time'] == 3) and (participantcsv['emotionPrimeStudy'] == 'happy'):
            return "25ms_happy"
        elif (participantcsv['study mask time'] == 3) and (participantcsv['emotionPrimeStudy'] == 'sad'):
            return "25ms_sad"
        elif (participantcsv['study mask time'] == 3) and (participantcsv['emotionPrimeStudy'] == 'neutral'):
            return "25ms_neutral"           
        
        elif (participantcsv['study mask time'] == 17) and (participantcsv['emotionPrimeStudy'] == 'happy'):
            return "141ms_happy"
        elif (participantcsv['study mask time'] == 17) and (participantcsv['emotionPrimeStudy'] == 'sad'):
            return "141ms_sad"
        elif (participantcsv['study mask time'] == 17) and (participantcsv['emotionPrimeStudy'] == 'neutral'):
            return "141ms_neutral"              
        else:
            return 0
    
    participantcsv['Conditions'] = participantcsv.apply(conditions, axis=1)
        
    ##### ##### ##### ##### ##### ##### ##### ##### ##### 
    #because of bad timing, we select only trials with good timing ####
    #get primer time
    primer_time_started = participantcsv['image_primer_study.started']
    primer_time_stopped = participantcsv['image_primer_study.stopped']
    primer_time = primer_time_stopped - primer_time_started
    #add column with primer time to csvdata
    participantcsv['primer time'] = primer_time
    #select data with correct timing #jitter between 4ms (+-2ms)
    participantcsv_8ms = participantcsv[participantcsv['primer time'].between(0.00633, 0.01033)]
    participantcsv_16ms = participantcsv[participantcsv['primer time'].between(0.01466,0.01866)]
    participantcsv_25ms = participantcsv[participantcsv['primer time'].between(0.023,0.027)]
    participantcsv_141ms = participantcsv[participantcsv['primer time'].between(0.1000,0.15000)]
    #append dataframes to one corrected dataframe
    participantcsv = participantcsv_8ms.append(participantcsv_16ms).append(participantcsv_25ms).append(participantcsv_141ms) #append csv to first csv  ]
    
    #Just get values smaller than 1.5
    participantcsv = participantcsv[(participantcsv['key_resp_study.rt'] <= 1.5)] 
    #Drop trials without reaction
    participantcsv = participantcsv.dropna(subset=['key_resp_study.rt'])
    ##### ##### ##### ##### ##### ##### ##### ##### ##### 
    #Get stuff
    #get correct answers
    corr_answers = participantcsv['key_resp_study.corr']
    reaction_time = participantcsv['key_resp_study.rt']

    uncon_8ms = participantcsv[(participantcsv['study mask time'] == 1)] 
    uncon_16ms = participantcsv[(participantcsv['study mask time'] == 2)] 
    uncon_25ms = participantcsv[(participantcsv['study mask time'] == 3)] 
    con_141ms = participantcsv[(participantcsv['study mask time'] == 17)] 
    
    #Get 12 conditions
    uncon_8ms_happy = uncon_8ms[(uncon_8ms['emotionPrimeStudy'] == 'happy')]
    uncon_8ms_sad = uncon_8ms[(uncon_8ms['emotionPrimeStudy'] == 'sad')]
    uncon_8ms_neutral = uncon_8ms[(uncon_8ms['emotionPrimeStudy'] == 'neutral')]
    
    uncon_16ms_happy = uncon_16ms[(uncon_16ms['emotionPrimeStudy'] == 'happy')]
    uncon_16ms_sad = uncon_16ms[(uncon_16ms['emotionPrimeStudy'] == 'sad')]
    uncon_16ms_neutral = uncon_16ms[(uncon_16ms['emotionPrimeStudy'] == 'neutral')]
    
    uncon_25ms_happy = uncon_25ms[(uncon_25ms['emotionPrimeStudy'] == 'happy')]
    uncon_25ms_sad = uncon_25ms[(uncon_25ms['emotionPrimeStudy'] == 'sad')]
    uncon_25ms_neutral = uncon_25ms[(uncon_25ms['emotionPrimeStudy'] == 'neutral')]
    
    con_141ms_happy = con_141ms[(con_141ms['emotionPrimeStudy'] == 'happy')]
    con_141ms_sad = con_141ms[(con_141ms['emotionPrimeStudy'] == 'sad')]
    con_141ms_neutral = con_141ms[(con_141ms['emotionPrimeStudy'] == 'neutral')]
    
    
    #Excecute functions and get one value for each participant
    reactionTime_uncon_8ms_happy(participantcsv,i)
    reactionTime_uncon_8ms_sad(participantcsv,i)
    reactionTime_uncon_8ms_neutral(participantcsv,i)
    
    reactionTime_uncon_16ms_happy(participantcsv,i)
    reactionTime_uncon_16ms_sad(participantcsv,i)
    reactionTime_uncon_16ms_neutral(participantcsv,i)
    
    reactionTime_uncon_25ms_happy(participantcsv,i)
    reactionTime_uncon_25ms_sad(participantcsv,i)
    reactionTime_uncon_25ms_neutral(participantcsv,i)
    
    reactionTime_con_141ms_happy(participantcsv,i)
    reactionTime_con_141ms_sad(participantcsv,i)
    reactionTime_con_141ms_neutral(participantcsv,i)
    
    name(participantcsv,i)
    numbercorrans(participantcsv,i)
    reactionnumber(participantcsv,i)
    reactiontotal(participantcsv,i)
    
    participant_ID=name(participantcsv,i)
    
    
    #save written dataframe from each participant
    # get ID of participant for csv files
    ID_1 = participantcsv['participant'].tolist()
    ID = ID_1[0]
    # create filename
    file_name=str(ID)+"_Reactions"+".csv"

    # save one csv file for each participant with all reactions
    #df_all_reactions.to_csv(r'C:/Users/juhoffmann/OneDrive - Uniklinik RWTH Aachen/Auswertung/Pilot2/FistLevel/'+file_name ,sep =';', index = False)
    df_all_reactions.to_csv(r'C:/Users/juhoffmann/OneDrive - Uniklinik RWTH Aachen/Auswertung/Pilot2/AllConditioins/FirstLevel/'+file_name ,sep =';', index = False)


    
    ##### HDDM #####
    
    #get reaction times
    reaction_time = participantcsv['key_resp_study.rt']            # reaction time
    #get accuracy
    correctness = participantcsv['key_resp_study.corr']            # get accuracy
    #get emotions from primer
    PrimeMaskTime = participantcsv['study mask time']              # extract emotion
    #get emotions from primer
    PrimeEmotion = participantcsv['emotionPrimeStudy']             # extract emotion
    #get correct answers
    corr_answers = participantcsv['key_resp_study.corr']
    #get block nummber
    block_number = participantcsv['Block']
    #get trial number
    trial_number = participantcsv['study trial']
    #get key response
    keyResponse = participantcsv['key_resp_study.keys']
    #get index of trial numbers (real trial number from 1-360)
    trial_index = participantcsv['index']
    #get conditions
    conditions = participantcsv['Conditions']

    
    #additional dataframe to merge reactions for hddm or GGLM analysis
    d_hddm = {'subj_idx': participant_ID,
               'rt': reaction_time,
              'correct': correctness,
               'response': keyResponse,
               'stim': PrimeEmotion, 
               'level': PrimeMaskTime,
               'real_trial_number': trial_index,
               'trial': trial_number,
               'block': block_number,
               'conditions':conditions}
    df_hddm = pd.DataFrame(data=d_hddm)
    
    
    file_name1=str(ID)+"_Reactions_hddm"+".csv"
    df_hddm.to_csv(r'C:/Users/juhoffmann/OneDrive - Uniklinik RWTH Aachen/Auswertung/Pilot2/AllConditioins/FirstLevel/'+file_name1 ,sep =';', index = False)

# %% [markdown]
# # Merge

# %%
#read in csv with extracted reactions
#participant = glob.glob('/Users/julia/OneDrive - Uniklinik RWTH Aachen/Auswertung/Pilot2/AllConditioins/FirstLevel/*_Reactions.csv') 
participant = glob.glob('C:/Users/juhoffmann/OneDrive - Uniklinik RWTH Aachen/Auswertung/Pilot2/AllConditioins/FirstLevel/*_Reactions.csv') 

#Need this to create a list
rows = [*range(1,1)] 
data = {'': rows}    
df_all = pd.DataFrame(data)

for i in participant:
    participantcsv = pd.read_csv(i, sep = ";")
    df_all = df_all.append(participantcsv) #append csv to first csv  
# save df_all    
#df_all.to_csv(r'/Users/julia/OneDrive - Uniklinik RWTH Aachen/Auswertung/Pilot2/AllConditioins/SecondLevel/All_ReactionTime.csv',sep =',', index = False)
df_all.to_csv(r'C:/Users/juhoffmann/OneDrive - Uniklinik RWTH Aachen/Auswertung/Pilot2/AllConditioins/SecondLevel/All_ReactionTime.csv',sep =',', index = False)

# %%
df_all
# Out:
#          Unnamed: 0  uncon_8ms_happy  uncon_8ms_sad  uncon_8ms_neutral  \
# 0   NaN         1.0              NaN            NaN                NaN
# 1   NaN         2.0              NaN            NaN                NaN
# 2   NaN         3.0              NaN            NaN                NaN
# 3   NaN         4.0              NaN            NaN                NaN
# 4   NaN         5.0              NaN            NaN                NaN
# ..   ..         ...              ...            ...                ...
# 363 NaN       364.0              NaN       0.368232                NaN
# 364 NaN       365.0              NaN       0.413523                NaN
# 365 NaN       366.0              NaN            NaN           0.393607
# 366 NaN       367.0         0.364432            NaN                NaN
# 367 NaN       368.0              NaN            NaN                NaN
#
#      uncon_16ms_happy  uncon_16ms_sad  uncon_16ms_neutral  uncon_25ms_happy  \
# ...

# %% [markdown]
# # Get HDDM Dataset

# %%
#read in csv with extracted reactions
#participant = glob.glob('/Users/julia/OneDrive - Uniklinik RWTH Aachen/Auswertung/Pilot2/AllConditioins/FirstLevel/*_hddm.csv') 
participant = glob.glob('C:/Users/juhoffmann/OneDrive - Uniklinik RWTH Aachen/Auswertung/Pilot2/AllConditioins/FirstLevel/*_hddm.csv') 

#Need this to create a list
rows = [*range(1,1)] 
data = {'': rows}    
df_all = pd.DataFrame(data)

for i in participant:
    participantcsv = pd.read_csv(i, sep = ";")
    df_all = df_all.append(participantcsv) #append csv to first csv  

df_all['level'] = df_all['level'].replace([3.0],'25ms')
df_all['level'] = df_all['level'].replace([2.0],'16ms')
df_all['level'] = df_all['level'].replace([1.0],'8ms')
df_all['level'] = df_all['level'].replace([17.0],'141ms')
df_all = df_all.replace("a", "sad").replace("s","neutral").replace("d","happy")
#df_all = hddm2.replace("sad", 1).replace("happy",2).replace("neutral",3)    
    
# save df_all    
#df_all.to_csv(r'/Users/julia/OneDrive - Uniklinik RWTH Aachen/Auswertung/Pilot2/AllConditioins/SecondLevel/hddm_data.csv',sep =',', index = False)
df_all.to_csv(r'C:/Users/juhoffmann/OneDrive - Uniklinik RWTH Aachen/Auswertung/Pilot2/GLMM/hddm_data.csv',sep =',', index = False)

# %%
df_all
# Out:
#                subj_idx        rt  correct response     stim  level  \
# 0   NaN       EmoCon002  0.882655      1.0  neutral  neutral    8ms
# 1   NaN       EmoCon002  0.615015      1.0  neutral  neutral    8ms
# 2   NaN       EmoCon002  0.546029      1.0  neutral  neutral    8ms
# 3   NaN       EmoCon002  1.177777      0.0    happy  neutral    8ms
# 4   NaN       EmoCon002  1.255196      0.0      sad    happy    8ms
# ..   ..             ...       ...      ...      ...      ...    ...
# 226 NaN  EMOCONPILOT024  0.404691      1.0    happy    happy  141ms
# 227 NaN  EMOCONPILOT024  0.406779      1.0      sad      sad  141ms
# 228 NaN  EMOCONPILOT024  0.371364      1.0    happy    happy  141ms
# 229 NaN  EMOCONPILOT024  0.647533      1.0      sad      sad  141ms
# 230 NaN  EMOCONPILOT024  0.733258      1.0    happy    happy  141ms
#
#      real_trial_number  trial  block   conditions
# 0                246.0    5.0    3.0  8ms_neutral
# ...

# %%
acc = pd.read_csv('C:/Users/juhoffmann/OneDrive - Uniklinik RWTH Aachen/Auswertung/Pilot2/AllConditioins/SecondLevel/Mean_Accuracy.csv', sep=";")

# %%
if df_all['subj_idex']=='EmoCon002':
    df_all['accuracy'] ==
# Out:
#     Unnamed: 0                  name  number of reactions  \
# 0            0        EMOCONPILOT001                  227
# 1            1             EmoCon002                  227
# 2            2        EMOCONPILOT003                  197
# 3            3        EMOCONPILOT004                  164
# 4            4  EMOCONPILOT005_120HZ                  270
# 5            5        EMOCONPILOT006                  228
# 6            6        EMOCONPILOT007                  137
# 7            7        EMOCONPILOT008                  235
# 8            8        EMOCONPILOT009                  247
# 9            9        EMOCONPILOT010                  224
# 10          10        EMOCONPILOT011                  221
# 11          11        EMOCONPILOT014                  102
# 12          12        EMOCONPILOT015                  182
# 13          13        EMOCONPILOT016                  227
# 14          14        EMOCONPILOT017                  232
# ...
