# %% [markdown]
# # Second Level Statistics with behavioural data
#
# ***
#  Use the csv created in `ExtractData`
#
#   1. Descriptive  statistic
#   2. Shapiro Wilk to test normality
#   3. Homoscedasticity to test equality of variance
#   4. ANOVA to test for differences
#   5. Paired T-Test  (normal distributed data)
#   6.  Wilcoxon signed-rank test (not normal distributed data)
# ***
# - Analyse mean Reaction times (`Mean_Reactions_selected.csv`)
# - Analyse mean Accuracy (`Mean_Accuracy_selected.csv`)
# ***
# Theoretical Background

# %%
#import modules 
import pandas as pd
import ast, os
import numpy as np
import csv
import fileinput
import glob
import seaborn as sns
import pingouin as pg
from pingouin import ttest

# %% [markdown]
# # Mean Reaction times
#
# Define and execute functions to analyse  mean reaction times using the csv created in "ExtractData" wit mean Reactions `Mean_ReactionTime.csv`

# %%
mean_reactions = pd.read_csv('C:/Users/Sara Halmans/Documents/Sara/Studium Lübeck/Praktikum Aachen/EEG_fMRT_Depressionsstudie/Datenanalyse Pilotstudie/Mean_ReactionTime.csv', sep = ";")

# %%
del mean_reactions['Unnamed: 0'] 
mean_reactions
# Out:
#                     name  number of reactions  number of correct answers  \
# 0         EMOCONPILOT009                  247                        171
# 1         EMOCONPILOT024                  231                        146
# 2         EMOCONPILOT003                  197                        150
# 3         EMOCONPILOT014                  102                         91
# 4         EMOCONPILOT022                  192                        139
# 5         EMOCONPILOT006                  228                        140
# 6              EmoCon002                  227                        169
# 7         EMOCONPILOT004                  164                        127
# 8         EMOCONPILOT008                  235                        187
# 9         EMOCONPILOT018                  213                        147
# 10        EMOCONPILOT015                  182                        165
# 11        EMOCONPILOT007                  137                        110
# ...

# %% [markdown]
# ### Create variables for each condition

# %%
reaction_8ms_happy = mean_reactions['reactionTime 8ms happy']
reaction_8ms_sad = mean_reactions['reactionTime 8ms sad']
reaction_8ms_neutral = mean_reactions['reactionTime 8ms neutral']
reaction_16ms_happy = mean_reactions['reactionTime 16ms happy']
reaction_16ms_sad = mean_reactions['reactionTime 16ms sad']
reaction_16ms_neutral = mean_reactions['reactionTime 16ms neutral']
reaction_25ms_happy = mean_reactions['reactionTime 25ms happy']
reaction_25ms_sad = mean_reactions['reactionTime 25ms sad']
reaction_25ms_neutral = mean_reactions['reactionTime 25ms neutral']
reaction_141ms_happy = mean_reactions['reactionTime 141ms happy']
reaction_141ms_sad = mean_reactions['reactionTime 141ms sad']
reaction_141ms_neutral = mean_reactions['reactionTime 141ms neutral']

# %%
# Descriptive statistics
desc_stat = mean_reactions.describe()
desc_stat = pd.DataFrame(desc_stat) 
desc_stat
# Out:
#        number of reactions  number of correct answers  \
# count            20.000000                  20.000000
# mean            209.900000                 155.600000
# std              39.035611                  27.211453
# min             102.000000                  91.000000
# 25%             195.750000                 144.500000
# 50%             225.500000                 160.000000
# 75%             231.250000                 169.500000
# max             270.000000                 214.000000
#
#        reactionTime total trials  reactionTime 8ms happy  \
# count                  20.000000               20.000000
# mean                    0.708547                0.793393
# std                     0.098846                0.164370
# min                     0.568923                0.558948
# 25%                     0.634555                0.674694
# 50%                     0.689689                0.764551
# 75%                     0.766213                0.885617
# ...

# %% [markdown]
# ### Normality test for each variable

# %%
# Normality test
n_one = pg.normality(reaction_8ms_happy, alpha=.05)
n_two = pg.normality(reaction_8ms_sad, alpha=.05)
n_three = pg.normality(reaction_8ms_neutral, alpha=.05)
n_four = pg.normality(reaction_16ms_happy, alpha=.05)
n_five = pg.normality(reaction_16ms_sad, alpha=.05)
n_six = pg.normality(reaction_16ms_neutral, alpha=.05)
n_seven = pg.normality(reaction_25ms_happy, alpha=.05)
n_eight = pg.normality(reaction_25ms_sad, alpha=.05)
n_nine = pg.normality(reaction_25ms_neutral, alpha=.05)
n_ten = pg.normality(reaction_141ms_happy, alpha=.05)
n_eleven = pg.normality(reaction_141ms_sad, alpha=.05)
n_twelve = pg.normality(reaction_141ms_neutral, alpha=.05)

normality = pd.DataFrame(n_one)
normality = normality.append(n_two).append(n_three).append(n_four).append(n_five).append(n_six).append(n_seven).append(n_eight).append(n_nine).append(n_ten).append(n_eleven).append(n_twelve)
normality['Comparison'] = ['reaction_8ms_happy',
                                'reaction_8ms_sad',
                                'reaction_8ms_neutral',
                                'reaction_16ms_happy',
                                'reaction_16ms_sad',
                                'reaction_16ms_neutral',
                                'reaction_25ms_happy',
                                'reaction_25ms_sad',
                                'reaction_25ms_neutral',
                                'reaction_141ms_happy',
                                'reaction_141ms_sad',
                                'reaction_141ms_neutral']

# %%
normality
# False für: reaction_8ms_sad
# False für: reaction_141ms_happy
# False für: reaction_141ms_neutral
# Out:
#                                    W          pval  normal  \
# reactionTime 8ms happy      0.942644  2.688822e-01    True
# reactionTime 8ms sad        0.894721  3.287150e-02   False
# reactionTime 8ms neutral    0.913355  7.386628e-02    True
# reactionTime 16ms happy     0.918759  9.378616e-02    True
# reactionTime 16ms sad       0.968418  7.211702e-01    True
# reactionTime 16ms neutral   0.955151  4.520578e-01    True
# reactionTime 25ms happy     0.924430  1.206055e-01    True
# reactionTime 25ms sad       0.955586  4.598553e-01    True
# reactionTime 25ms neutral   0.961103  5.661089e-01    True
# reactionTime 141ms happy    0.904381  4.986079e-02   False
# reactionTime 141ms sad      0.937615  2.160599e-01    True
# reactionTime 141ms neutral  0.524382  5.323765e-07   False
#
#                                         Comparison
# reactionTime 8ms happy          reaction_8ms_happy
# reactionTime 8ms sad              reaction_8ms_sad
# ...

# %%
# The homogeneity of variances 
homosc = pg.homoscedasticity(mean_reactions[['reactionTime 8ms happy',
                                'reactionTime 8ms sad',
                                'reactionTime 8ms neutral',
                                'reactionTime 16ms happy',
                                'reactionTime 16ms sad',
                                'reactionTime 16ms neutral',
                                'reactionTime 25ms happy',
                                'reactionTime 25ms sad',
                                'reactionTime 25ms neutral',
                                'reactionTime 141ms happy',
                                'reactionTime 141ms sad',
                                'reactionTime 141ms neutral']],
                    method ='bartlett') #all normal distributed
homosc = pd.DataFrame(homosc)

# %% [markdown]
# ### Anova

# %%
anova = pg.rm_anova(mean_reactions)
anova.round(3)

anova = pd.DataFrame(anova)

# %% [markdown]
# ## Paired t test
# Only for variables with normal distribution.

# %% [markdown]
# #### t tests for condition: reaction_8ms_happy

# %%
one = ttest(reaction_8ms_happy, reaction_8ms_neutral, paired=True, tail='two-sided').round(4)

two = ttest(reaction_8ms_happy, reaction_16ms_happy, paired=True, tail='two-sided').round(4)
three = ttest(reaction_8ms_happy, reaction_16ms_sad, paired=True, tail='two-sided').round(4)
four = ttest(reaction_8ms_happy, reaction_16ms_neutral, paired=True, tail='two-sided').round(4)

five = ttest(reaction_8ms_happy, reaction_25ms_happy, paired=True, tail='two-sided').round(4)
six = ttest(reaction_8ms_happy, reaction_25ms_sad, paired=True, tail='two-sided').round(4)
seven = ttest(reaction_8ms_happy, reaction_25ms_neutral, paired=True, tail='two-sided').round(4)

eight = ttest(reaction_8ms_happy, reaction_141ms_sad, paired=True, tail='two-sided').round(4)

# %% [markdown]
# #### remaining t tests for condition: reaction_8ms_neutral

# %%
nine = ttest(reaction_8ms_neutral, reaction_16ms_happy, paired=True, tail='two-sided').round(4)
ten = ttest(reaction_8ms_neutral, reaction_16ms_sad, paired=True, tail='two-sided').round(4)
eleven = ttest(reaction_8ms_neutral, reaction_16ms_neutral, paired=True, tail='two-sided').round(4)

twelve = ttest(reaction_8ms_neutral, reaction_25ms_happy, paired=True, tail='two-sided').round(4)
thirteen = ttest(reaction_8ms_neutral, reaction_25ms_sad, paired=True, tail='two-sided').round(4)
fourteen = ttest(reaction_8ms_neutral, reaction_25ms_neutral, paired=True, tail='two-sided').round(4)

fifteen = ttest(reaction_8ms_neutral, reaction_141ms_sad, paired=True, tail='two-sided').round(4)

# %% [markdown]
# #### remaining t tests for condition: reaction_16ms_happy

# %%
sixteen = ttest(reaction_16ms_happy, reaction_16ms_sad, paired=True, tail='two-sided').round(4)
seventeen = ttest(reaction_16ms_happy, reaction_16ms_neutral, paired=True, tail='two-sided').round(4)

eightteen = ttest(reaction_16ms_happy, reaction_25ms_happy, paired=True, tail='two-sided').round(4)
nineteen = ttest(reaction_16ms_happy, reaction_25ms_sad, paired=True, tail='two-sided').round(4)
twenty = ttest(reaction_16ms_happy, reaction_25ms_neutral, paired=True, tail='two-sided').round(4)
 
twentyone = ttest(reaction_16ms_happy, reaction_141ms_sad, paired=True, tail='two-sided').round(4)

# %% [markdown]
# #### remaining t tests for condition: reaction_16ms_sad

# %%
twentytwo = ttest(reaction_16ms_sad, reaction_16ms_neutral, paired=True, tail='two-sided').round(4)

twentythree = ttest(reaction_16ms_sad, reaction_25ms_happy, paired=True, tail='two-sided').round(4)
twentyfour = ttest(reaction_16ms_sad, reaction_25ms_sad, paired=True, tail='two-sided').round(4)
twentyfive = ttest(reaction_16ms_sad, reaction_25ms_neutral, paired=True, tail='two-sided').round(4)

twentysix = ttest(reaction_16ms_sad, reaction_141ms_sad, paired=True, tail='two-sided').round(4)

# %% [markdown]
# #### remaining t tests for condition: reaction_16ms_neutral

# %%
twentyseven = ttest(reaction_16ms_neutral, reaction_25ms_happy, paired=True, tail='two-sided').round(4)
twentyeight = ttest(reaction_16ms_neutral, reaction_25ms_sad, paired=True, tail='two-sided').round(4)
twentynine = ttest(reaction_16ms_neutral, reaction_25ms_neutral, paired=True, tail='two-sided').round(4)

thirty = ttest(reaction_16ms_neutral, reaction_141ms_sad, paired=True, tail='two-sided').round(4)

# %% [markdown]
# #### remaining t tests for condition: reaction_25ms_happy

# %%
thirtyone = ttest(reaction_25ms_happy, reaction_25ms_sad, paired=True, tail='two-sided').round(4)
thirtytwo = ttest(reaction_25ms_happy, reaction_25ms_neutral, paired=True, tail='two-sided').round(4)

thirtythree = ttest(reaction_25ms_happy, reaction_141ms_sad, paired=True, tail='two-sided').round(4)

# %% [markdown]
# #### remaining t tests for condition: reaction_25ms_sad

# %%
thirtyfour = ttest(reaction_25ms_sad, reaction_25ms_neutral, paired=True, tail='two-sided').round(4)

thirtyfive = ttest(reaction_25ms_sad, reaction_141ms_sad, paired=True, tail='two-sided').round(4)

# %% [markdown]
# #### remaining t tests for condition: reaction_25ms_neutral

# %%
thirtysix = ttest(reaction_25ms_neutral, reaction_141ms_sad, paired=True, tail='two-sided').round(4)

# %% [markdown]
# ## Create a DataFrame with the t test results

# %%
Ttest = pd.DataFrame(one)
Ttest = Ttest.append(two).append(three).append(four).append(five)
Ttest = Ttest.append(six).append(seven).append(eight).append(nine)
Ttest = Ttest.append(ten).append(eleven).append(twelve).append(thirteen)
Ttest = Ttest.append(fourteen).append(fifteen).append(sixteen).append(seventeen)
Ttest = Ttest.append(eightteen).append(nineteen).append(twenty).append(twentyone)
Ttest = Ttest.append(twentytwo).append(twentythree).append(twentyfour).append(twentyfive)
Ttest = Ttest.append(twentysix).append(twentyseven).append(twentyeight).append(twentynine)
Ttest = Ttest.append(thirty).append(thirtyone).append(thirtytwo).append(thirtythree)
Ttest = Ttest.append(thirtyfour).append(thirtyfive).append(thirtysix)
Ttest['Comparison'] = ['8ms happy vs. 8ms neutral', '8ms happy vs. 16ms happy',
                                     '8ms happy vs. 16ms sad', '8ms happy vs. 16ms neutral',
                                     '8ms happy vs. 25ms happy', '8ms happy vs. 25ms sad',
                                     '8ms happy vs. 25ms neutral', '8ms happy vs. 141ms sad',
                                     '8ms neutral vs. 16ms happy', '8ms neutral vs. 16ms sad',
                                     '8ms neutral vs. 16ms neutral', '8ms neutral vs. 25ms happy',
                                     '8ms neutral vs. 25ms sad', '8ms neutral vs. 25ms neutral',
                                     '8ms neutral vs. 141ms sad', '16ms happy vs. 16ms sad',
                                     '16ms happy vs. 16ms neutral', '16ms happy vs. 25ms happy',
                                     '16ms happy vs. 25ms sad', '16ms happy vs. 25ms neutral',
                                     '16ms happy vs. 141ms sad', '16ms sad vs. 16ms neutral',
                                     '16ms sad vs. 25ms happy', '16ms sad vs. 25ms sad',
                                     '16ms sad vs. 25ms neutral', '16ms sad vs. 141ms sad',
                                     '16ms neutral vs. 25ms happy', '16ms neutral vs. 25ms sad',
                                     '16ms neutral vs. 25ms neutral', '16ms neutral vs. 141ms sad',
                                     '25ms happy vs. 25ms sad', '25ms happy vs. 25ms neutral',
                                     '25ms happy vs. 141ms sad', '25ms sad vs. 25ms neutral',
                                     '25ms sad vs. 141ms sad', '25ms neutral vs. 141ms sad']

# %%
## weglassen
#bon =[(0.05/3),(0.05/3),(0.05/3),(0.05/3),(0.05/3),(0.05/3),(0.05/3),(0.05/3),
#      (0.05/3),(0.05/7),(0.05/7),(0.05/7),(0.05/7),(0.05/7),(0.05/7),(0.05/7)]
#bon = [round(i, 4) for i in bon] #round values
#Ttest['Bonferroni'] = bon

# %% [markdown]
# ## Wilcoxon test
# For variables without normal distribution.
# - reaction_8ms_sad
# - reaction_141ms_happy
# - reaction_141ms_neutral

# %% [markdown]
# #### Wilcoxon test for condition: reaction_8ms_sad

# %%
# Wilcox test for mean reaction 
thirtyseven = pg.wilcoxon(reaction_8ms_sad, reaction_8ms_happy, tail='two-sided').round(4)
thirtyeight = pg.wilcoxon(reaction_8ms_sad, reaction_8ms_neutral, tail='two-sided').round(4)

thirtynine = pg.wilcoxon(reaction_8ms_sad, reaction_16ms_happy, tail='two-sided').round(4)
forty = pg.wilcoxon(reaction_8ms_sad, reaction_16ms_sad, tail='two-sided').round(4)
fortyone = pg.wilcoxon(reaction_8ms_sad, reaction_16ms_neutral, tail='two-sided').round(4)

fortytwo = pg.wilcoxon(reaction_8ms_sad, reaction_25ms_happy, tail='two-sided').round(4)
fortythree = pg.wilcoxon(reaction_8ms_sad, reaction_25ms_sad, tail='two-sided').round(4)
fortyfour = pg.wilcoxon(reaction_8ms_sad, reaction_25ms_neutral, tail='two-sided').round(4)

fortyfive = pg.wilcoxon(reaction_8ms_sad, reaction_141ms_happy, tail='two-sided').round(4)
fortysix = pg.wilcoxon(reaction_8ms_sad, reaction_141ms_sad, tail='two-sided').round(4)
fortyseven = pg.wilcoxon(reaction_8ms_sad, reaction_141ms_neutral, tail='two-sided').round(4)

# %% [markdown]
# #### remaining Wilcoxon tests for condition: reaction_141ms_happy

# %%
fortyeight = pg.wilcoxon(reaction_141ms_happy, reaction_8ms_happy, tail='two-sided').round(4)
fortynine = pg.wilcoxon(reaction_141ms_happy, reaction_8ms_neutral, tail='two-sided').round(4)

fifty = pg.wilcoxon(reaction_141ms_happy, reaction_16ms_happy, tail='two-sided').round(4)
fiftyone = pg.wilcoxon(reaction_141ms_happy, reaction_16ms_sad, tail='two-sided').round(4)
fiftytwo = pg.wilcoxon(reaction_141ms_happy, reaction_16ms_neutral, tail='two-sided').round(4)

fiftythree = pg.wilcoxon(reaction_141ms_happy, reaction_25ms_happy, tail='two-sided').round(4)
fiftyfour = pg.wilcoxon(reaction_141ms_happy, reaction_25ms_sad, tail='two-sided').round(4)
fiftyfive = pg.wilcoxon(reaction_141ms_happy, reaction_25ms_neutral, tail='two-sided').round(4)

fiftysix = pg.wilcoxon(reaction_141ms_happy, reaction_141ms_sad, tail='two-sided').round(4)
fiftyseven = pg.wilcoxon(reaction_141ms_happy, reaction_141ms_neutral, tail='two-sided').round(4)

# %% [markdown]
# #### remaining Wilcoxon tests for condition: reaction_141ms_neutral

# %%
fiftyeight = pg.wilcoxon(reaction_141ms_neutral, reaction_8ms_happy, tail='two-sided').round(4)
fiftynine = pg.wilcoxon(reaction_141ms_neutral, reaction_8ms_neutral, tail='two-sided').round(4)

sixty = pg.wilcoxon(reaction_141ms_neutral, reaction_16ms_happy, tail='two-sided').round(4)
sixtyone = pg.wilcoxon(reaction_141ms_neutral, reaction_16ms_sad, tail='two-sided').round(4)
sixtytwo = pg.wilcoxon(reaction_141ms_neutral, reaction_16ms_neutral, tail='two-sided').round(4)

sixtythree = pg.wilcoxon(reaction_141ms_neutral, reaction_25ms_happy, tail='two-sided').round(4)
sixtyfour = pg.wilcoxon(reaction_141ms_neutral, reaction_25ms_sad, tail='two-sided').round(4)
sixtyfive = pg.wilcoxon(reaction_141ms_neutral, reaction_25ms_neutral, tail='two-sided').round(4)

sixtysix = pg.wilcoxon(reaction_141ms_neutral, reaction_141ms_sad, tail='two-sided').round(4)

# %% [markdown]
# ## Create a DataFrame with the Wilcoxon test results

# %%
wilcox = pd.DataFrame(thirtyseven)
wilcox = wilcox.append(thirtyeight).append(thirtynine).append(forty).append(fortyone)
wilcox = wilcox.append(fortytwo).append(fortythree).append(fortyfour).append(fortyfive)
wilcox = wilcox.append(fortysix).append(fortyseven).append(fortyeight).append(fortynine)
wilcox = wilcox.append(fifty).append(fiftyone).append(fiftytwo).append(fiftythree)
wilcox = wilcox.append(fiftyfour).append(fiftyfive).append(fiftysix).append(fiftyseven)
wilcox = wilcox.append(fiftyeight).append(fiftynine).append(sixty).append(sixtyone)
wilcox = wilcox.append(sixtytwo).append(sixtythree).append(sixtyfour).append(sixtyfive).append(sixtysix)

wilcox['Comparison'] = ['8ms sad vs. 8ms happy', '8ms sad vs. 8ms neutral',
                           '8ms sad vs. 16ms happy', '8ms sad vs. 16ms sad',
                           '8ms sad vs. 16ms neutral', '8ms sad vs. 25ms happy',
                           '8ms sad vs. 25ms sad', '8ms sad vs. 25ms neutral',
                           '8ms sad vs. 141ms happy', '8ms sad vs. 141ms sad',
                           '8ms sad vs. 141ms neutral', '141ms happy vs. 8ms happy',
                           '141ms happy vs. 8ms neutral', '141ms happy vs. 16ms happy',
                           '141ms happy vs. 16ms sad', '141ms happy vs. 16ms neutral',
                           '141ms happy vs. 25ms happy', '141ms happy vs. 25ms sad',
                           '141ms happy vs. 25ms neutral', '141ms happy vs. 141ms sad',
                           '141ms happy vs. 141ms neutral', '141ms neutral vs. 8ms happy',
                           '141ms neutral vs. 8ms neutral', '141ms neutral vs. 16ms happy',
                           '141ms neutral vs. 16ms sad', '141ms neutral vs. 16ms neutral',
                           '141ms neutral vs. 25ms happy', '141ms neutral vs. 25ms sad',
                           '141ms neutral vs. 25ms neutral', '141ms neutral vs. 141ms sad']

# %%
#bon =[(0.05/2),(0.05/2)]
#bon = [round(i, 4) for i in bon] #round values
#wilcox['Bonferroni'] = bon

# %% [markdown]
# ## Save the tables in Excle-files

# %%
# Save
desc_stat.to_csv('C:/Users/Sara Halmans/Documents/Sara/Studium Lübeck/Praktikum Aachen/EEG_fMRT_Depressionsstudie/Datenanalyse Pilotstudie/Second Level Statistics/Descriptive_stat_Reactions.csv',sep =';', index = True)
normality.to_csv('C:/Users/Sara Halmans/Documents/Sara/Studium Lübeck/Praktikum Aachen/EEG_fMRT_Depressionsstudie/Datenanalyse Pilotstudie/Second Level Statistics/Shapiro_Test_Reactions.csv',sep =';', index = True)
homosc.to_csv('C:/Users/Sara Halmans/Documents/Sara/Studium Lübeck/Praktikum Aachen/EEG_fMRT_Depressionsstudie/Datenanalyse Pilotstudie/Second Level Statistics/Homoscedasticity_Reactions.csv',sep =';', index = True)
anova.to_csv('C:/Users/Sara Halmans/Documents/Sara/Studium Lübeck/Praktikum Aachen/EEG_fMRT_Depressionsstudie/Datenanalyse Pilotstudie/Second Level Statistics/Anova_Reactions.csv',sep =';', index = True)
wilcox.to_csv('C:/Users/Sara Halmans/Documents/Sara/Studium Lübeck/Praktikum Aachen/EEG_fMRT_Depressionsstudie/Datenanalyse Pilotstudie/Second Level Statistics/Wilcox_Reactions.csv',sep =';', index = True)
Ttest.to_csv('C:/Users/Sara Halmans/Documents/Sara/Studium Lübeck/Praktikum Aachen/EEG_fMRT_Depressionsstudie/Datenanalyse Pilotstudie/Second Level Statistics/Ttest_Reactions.csv',sep =';', index = True)

# %% [markdown]
# # Mean Accuracy
#
# Define and execute functions to analyse  mean accuracy using the csv created in "ExctractData" wit mean Reactions `Mean_Accuracy_selected.csv`

# %%
mean_accuracy = pd.read_csv('C:/Users/Sara Halmans/Documents/Sara/Studium Lübeck/Praktikum Aachen/EEG_fMRT_Depressionsstudie/Datenanalyse Pilotstudie/Mean_Accuracy.csv', sep = ";")

# %%
del mean_accuracy['Unnamed: 0'] 
mean_accuracy
# Out:
#                     name  number of reactions  number of correct answers  \
# 0         EMOCONPILOT009                  247                        171
# 1         EMOCONPILOT024                  231                        146
# 2         EMOCONPILOT003                  197                        150
# 3         EMOCONPILOT014                  102                         91
# 4         EMOCONPILOT022                  192                        139
# 5         EMOCONPILOT006                  228                        140
# 6              EmoCon002                  227                        169
# 7         EMOCONPILOT004                  164                        127
# 8         EMOCONPILOT008                  235                        187
# 9         EMOCONPILOT018                  213                        147
# 10        EMOCONPILOT015                  182                        165
# 11        EMOCONPILOT007                  137                        110
# ...

# %% [markdown]
# ### Create variables for each condition

# %%
accuracy_8ms_happy = mean_accuracy['accuracy 8ms happy']
accuracy_8ms_sad = mean_accuracy['accuracy 8ms sad']
accuracy_8ms_neutral = mean_accuracy['accuracy 8ms neutral']
accuracy_16ms_happy = mean_accuracy['accuracy 16ms happy']
accuracy_16ms_sad = mean_accuracy['accuracy 16ms sad']
accuracy_16ms_neutral = mean_accuracy['accuracy 16ms neutral']
accuracy_25ms_happy = mean_accuracy['accuracy 25ms happy']
accuracy_25ms_sad = mean_accuracy['accuracy 25ms sad']
accuracy_25ms_neutral = mean_accuracy['accuracy 25ms neutral']
accuracy_141ms_happy = mean_accuracy['accuracy 141ms happy']
accuracy_141ms_sad = mean_accuracy['accuracy 141ms sad']
accuracy_141ms_neutral = mean_accuracy['accuracy 141ms neutral']

# %%
# Descriptive statistics
a_desc_stat = mean_accuracy.describe()
a_desc_stat = pd.DataFrame(a_desc_stat)

# %% [markdown]
# ### Normality test for each variable

# %%
# Normality Test
an_one = pg.normality(accuracy_8ms_happy, alpha=.05)
an_two = pg.normality(accuracy_8ms_sad, alpha=.05)
an_three = pg.normality(accuracy_8ms_neutral, alpha=.05)
an_four = pg.normality(accuracy_16ms_happy, alpha=.05)
an_five = pg.normality(accuracy_16ms_sad, alpha=.05)
an_six = pg.normality(accuracy_16ms_neutral, alpha=.05)
an_seven = pg.normality(accuracy_25ms_happy, alpha=.05)
an_eight = pg.normality(accuracy_25ms_sad, alpha=.05)
an_nine = pg.normality(accuracy_25ms_neutral, alpha=.05)
an_ten = pg.normality(accuracy_141ms_happy, alpha=.05)
an_eleven = pg.normality(accuracy_141ms_sad, alpha=.05)
an_twelve = pg.normality(accuracy_141ms_neutral, alpha=.05)

a_normality = pd.DataFrame(an_one)
a_normality = a_normality.append(an_two).append(an_three).append(an_four).append(an_five).append(an_six).append(an_seven).append(an_eight).append(an_nine).append(an_ten).append(an_eleven).append(an_twelve)
a_normality['Comparison'] = ['accuracy_8ms_happy',
                                'accuracy_8ms_sad',
                                'accuracy_8ms_neutral',
                                'accuracy_16ms_happy',
                                'accuracy_16ms_sad',
                                'accuracy_16ms_neutral',
                                'accuracy_25ms_happy',
                                'accuracy_25ms_sad',
                                'accuracy_25ms_neutral',
                                'accuracy_141ms_happy',
                                'accuracy_141ms_sad',
                                'accuracy_141ms_neutral']

# %%
a_normality
#nur True für: accuracy 25ms sad
# und:         accuracy 141ms sad
# Out:
#                                W          pval  normal              Comparison
# accuracy 8ms happy      0.891275  2.838561e-02   False      accuracy_8ms_happy
# accuracy 8ms sad        0.632944  6.589723e-06   False        accuracy_8ms_sad
# accuracy 8ms neutral    0.874124  1.389387e-02   False    accuracy_8ms_neutral
# accuracy 16ms happy     0.750092  1.702464e-04   False     accuracy_16ms_happy
# accuracy 16ms sad       0.885912  2.263617e-02   False       accuracy_16ms_sad
# accuracy 16ms neutral   0.873414  1.349708e-02   False   accuracy_16ms_neutral
# accuracy 25ms happy     0.777249  4.032754e-04   False     accuracy_25ms_happy
# accuracy 25ms sad       0.954239  4.360378e-01    True       accuracy_25ms_sad
# accuracy 25ms neutral   0.816752  1.552699e-03   False   accuracy_25ms_neutral
# accuracy 141ms happy    0.661940  1.387008e-05   False    accuracy_141ms_happy
# accuracy 141ms sad      0.926645  1.330654e-01    True      accuracy_141ms_sad
# ...

# %%
# The homogeneity of variances 
a_homosc = pg.homoscedasticity(mean_accuracy[['accuracy 8ms happy',
                                'accuracy 8ms sad',
                                'accuracy 8ms neutral',
                                'accuracy 16ms happy',
                                'accuracy 16ms sad',
                                'accuracy 16ms neutral',
                                'accuracy 25ms happy',
                                'accuracy 25ms sad',
                                'accuracy 25ms neutral',
                                'accuracy 141ms happy',
                                'accuracy 141ms sad',
                                'accuracy 141ms neutral']],
                             method ='bartlett') #for normal distributed
a_homosc = pd.DataFrame(a_homosc)

a_homoscL = pg.homoscedasticity(mean_accuracy[['accuracy 8ms happy',
                                'accuracy 8ms sad',
                                'accuracy 8ms neutral',
                                'accuracy 16ms happy',
                                'accuracy 16ms sad',
                                'accuracy 16ms neutral',
                                'accuracy 25ms happy',
                                'accuracy 25ms sad',
                                'accuracy 25ms neutral',
                                'accuracy 141ms happy',
                                'accuracy 141ms sad',
                                'accuracy 141ms neutral']],
                              method ='levene') #for not normal distributed
a_homoscL = pd.DataFrame(a_homoscL)
a_homosc = a_homosc.append(a_homoscL)

# %% [markdown]
# ### Anova

# %%
a_anova = pg.rm_anova(mean_accuracy)
a_anova.round(3)
a_anova = pd.DataFrame(a_anova)

# %% [markdown]
# ## Paired t test
# For variables with normal distribution.
# - accuracy 25ms sad
# - accuracy 141ms sad

# %% [markdown]
# #### t test for condition: accuracy 25ms sad

# %%
a_one = ttest(accuracy_25ms_sad, accuracy_141ms_sad, paired=True, tail='two-sided').round(4)

# %% [markdown]
# ## Create a DataFrame with the t test results

# %%
a_Ttest = pd.DataFrame(a_one)
a_Ttest['Comparison'] = ['accuracy 25ms sad vs. accuracy 141ms sad']

# %%
#bon = [(0.05/2),(0.05/2),(0.05/2),(0.05/2),(0.05/2),(0.05/2),
#       (0.05/6),(0.05/6),(0.05/6),(0.05/6),(0.05/6),(0.05/6)]
#bon = [round(i, 4) for i in bon] #round values                                
#Ttest['Bonferroni'] = bon

# %% [markdown]
# ## Wilcoxon test
# For variables without normal distribution.

# %% [markdown]
# #### Wilcoxon test for condition: accuracy 8ms happy

# %%
a_two = pg.wilcoxon(accuracy_8ms_happy, accuracy_8ms_sad, tail='two-sided').round(4)
a_three = pg.wilcoxon(accuracy_8ms_happy, accuracy_8ms_neutral, tail='two-sided').round(4)

a_four = pg.wilcoxon(accuracy_8ms_happy, accuracy_16ms_happy, tail='two-sided').round(4)
a_five = pg.wilcoxon(accuracy_8ms_happy, accuracy_16ms_sad, tail='two-sided').round(4)
a_six = pg.wilcoxon(accuracy_8ms_happy, accuracy_16ms_neutral, tail='two-sided').round(4)

a_seven = pg.wilcoxon(accuracy_8ms_happy, accuracy_25ms_happy, tail='two-sided').round(4)
a_eight = pg.wilcoxon(accuracy_8ms_happy, accuracy_25ms_sad, tail='two-sided').round(4)
a_nine = pg.wilcoxon(accuracy_8ms_happy, accuracy_25ms_neutral, tail='two-sided').round(4)

a_ten = pg.wilcoxon(accuracy_8ms_happy, accuracy_141ms_happy, tail='two-sided').round(4)
a_eleven = pg.wilcoxon(accuracy_8ms_happy, accuracy_141ms_sad, tail='two-sided').round(4)
a_twelve = pg.wilcoxon(accuracy_8ms_happy, accuracy_141ms_neutral, tail='two-sided').round(4)

# %% [markdown]
# #### remaining Wilcoxon test for condition: accuracy 8ms sad

# %%
a_thirteen = pg.wilcoxon(accuracy_8ms_sad, accuracy_8ms_neutral, tail='two-sided').round(4)

a_fourteen = pg.wilcoxon(accuracy_8ms_sad, accuracy_16ms_happy, tail='two-sided').round(4)
a_fifteen = pg.wilcoxon(accuracy_8ms_sad, accuracy_16ms_sad, tail='two-sided').round(4)
a_sixteen = pg.wilcoxon(accuracy_8ms_sad, accuracy_16ms_neutral, tail='two-sided').round(4)

a_seventeen = pg.wilcoxon(accuracy_8ms_sad, accuracy_25ms_happy, tail='two-sided').round(4)
a_eightteen = pg.wilcoxon(accuracy_8ms_sad, accuracy_25ms_sad, tail='two-sided').round(4)
a_nineteen = pg.wilcoxon(accuracy_8ms_sad, accuracy_25ms_neutral, tail='two-sided').round(4)

a_twenty = pg.wilcoxon(accuracy_8ms_sad, accuracy_141ms_happy, tail='two-sided').round(4)
a_twentyone = pg.wilcoxon(accuracy_8ms_sad, accuracy_141ms_sad, tail='two-sided').round(4)
a_twentytwo = pg.wilcoxon(accuracy_8ms_sad, accuracy_141ms_neutral, tail='two-sided').round(4)

# %% [markdown]
# #### remaining Wilcoxon tests for condition: accuracy 8ms neutral

# %%
a_twentythree = pg.wilcoxon(accuracy_8ms_neutral, accuracy_16ms_happy, tail='two-sided').round(4)
a_twentyfour = pg.wilcoxon(accuracy_8ms_neutral, accuracy_16ms_sad, tail='two-sided').round(4)
a_twentyfive = pg.wilcoxon(accuracy_8ms_neutral, accuracy_16ms_neutral, tail='two-sided').round(4)

a_twentysix = pg.wilcoxon(accuracy_8ms_neutral, accuracy_25ms_happy, tail='two-sided').round(4)
a_twentyseven = pg.wilcoxon(accuracy_8ms_neutral, accuracy_25ms_sad, tail='two-sided').round(4)
a_twentyeight = pg.wilcoxon(accuracy_8ms_neutral, accuracy_25ms_neutral, tail='two-sided').round(4)

a_twentynine = pg.wilcoxon(accuracy_8ms_neutral, accuracy_141ms_happy, tail='two-sided').round(4)
a_thirty = pg.wilcoxon(accuracy_8ms_neutral, accuracy_141ms_sad, tail='two-sided').round(4)
a_thirtyone = pg.wilcoxon(accuracy_8ms_neutral, accuracy_141ms_neutral, tail='two-sided').round(4)

# %% [markdown]
# #### remaining Wilcoxon tests for condition: accuracy 16ms happy

# %%
a_thirtytwo = pg.wilcoxon(accuracy_16ms_happy, accuracy_16ms_sad, tail='two-sided').round(4)
a_thirtythree = pg.wilcoxon(accuracy_16ms_happy, accuracy_16ms_neutral, tail='two-sided').round(4)

a_thirtyfour = pg.wilcoxon(accuracy_16ms_happy, accuracy_25ms_happy, tail='two-sided').round(4)
a_thirtyfive = pg.wilcoxon(accuracy_16ms_happy, accuracy_25ms_sad, tail='two-sided').round(4)
a_thirtysix = pg.wilcoxon(accuracy_16ms_happy, accuracy_25ms_neutral, tail='two-sided').round(4)

a_thirtyseven = pg.wilcoxon(accuracy_16ms_happy, accuracy_141ms_happy, tail='two-sided').round(4)
a_thirtyeight = pg.wilcoxon(accuracy_16ms_happy, accuracy_141ms_sad, tail='two-sided').round(4)
a_thirtynine = pg.wilcoxon(accuracy_16ms_happy, accuracy_141ms_neutral, tail='two-sided').round(4)

# %% [markdown]
# #### remaining Wilcoxon tests for condition: accuracy 16ms sad

# %%
a_forty = pg.wilcoxon(accuracy_16ms_sad, accuracy_16ms_neutral, tail='two-sided').round(4)

a_fortyone = pg.wilcoxon(accuracy_16ms_sad, accuracy_25ms_happy, tail='two-sided').round(4)
a_fortytwo = pg.wilcoxon(accuracy_16ms_sad, accuracy_25ms_sad, tail='two-sided').round(4)
a_fortythree = pg.wilcoxon(accuracy_16ms_sad, accuracy_25ms_neutral, tail='two-sided').round(4)

a_fortyfour = pg.wilcoxon(accuracy_16ms_sad, accuracy_141ms_happy, tail='two-sided').round(4)
a_fortyfive = pg.wilcoxon(accuracy_16ms_sad, accuracy_141ms_sad, tail='two-sided').round(4)
a_fortysix = pg.wilcoxon(accuracy_16ms_sad, accuracy_141ms_neutral, tail='two-sided').round(4)

# %% [markdown]
# #### remaining Wilcoxon tests for condition: accuracy 16ms neutral

# %%
a_fortyseven = pg.wilcoxon(accuracy_16ms_neutral, accuracy_25ms_happy, tail='two-sided').round(4)
a_fortyeight = pg.wilcoxon(accuracy_16ms_neutral, accuracy_25ms_sad, tail='two-sided').round(4)
a_fortynine = pg.wilcoxon(accuracy_16ms_neutral, accuracy_25ms_neutral, tail='two-sided').round(4)

a_fifty = pg.wilcoxon(accuracy_16ms_neutral, accuracy_141ms_happy, tail='two-sided').round(4)
a_fiftyone = pg.wilcoxon(accuracy_16ms_neutral, accuracy_141ms_sad, tail='two-sided').round(4)
a_fiftytwo = pg.wilcoxon(accuracy_16ms_neutral, accuracy_141ms_neutral, tail='two-sided').round(4)

# %% [markdown]
# #### remaining Wilcoxon tests for condition: accuracy 25ms happy

# %%
a_fiftythree = pg.wilcoxon(accuracy_25ms_happy, accuracy_25ms_sad, tail='two-sided').round(4)
a_fiftyfour = pg.wilcoxon(accuracy_25ms_happy, accuracy_25ms_neutral, tail='two-sided').round(4)

a_fiftyfive = pg.wilcoxon(accuracy_25ms_happy, accuracy_141ms_happy, tail='two-sided').round(4)
a_fiftysix = pg.wilcoxon(accuracy_25ms_happy, accuracy_141ms_sad, tail='two-sided').round(4)
a_fiftyseven = pg.wilcoxon(accuracy_25ms_happy, accuracy_141ms_neutral, tail='two-sided').round(4)

# %% [markdown]
# #### remaining Wilcoxon tests for condition: accuracy 25ms sad

# %%
a_fiftyeight = pg.wilcoxon(accuracy_25ms_sad, accuracy_25ms_neutral, tail='two-sided').round(4)

a_fiftynine = pg.wilcoxon(accuracy_25ms_sad, accuracy_141ms_happy, tail='two-sided').round(4)
a_sixty = pg.wilcoxon(accuracy_25ms_sad, accuracy_141ms_neutral, tail='two-sided').round(4)

# %% [markdown]
# #### remaining Wilcoxon tests for condition: accuracy 25ms neutral

# %%
a_sixtyone = pg.wilcoxon(accuracy_25ms_neutral, accuracy_141ms_happy, tail='two-sided').round(4)
a_sixtytwo = pg.wilcoxon(accuracy_25ms_neutral, accuracy_141ms_sad, tail='two-sided').round(4)
a_sixtythree = pg.wilcoxon(accuracy_25ms_neutral, accuracy_141ms_neutral, tail='two-sided').round(4)

# %% [markdown]
# #### remaining Wilcoxon tests for condition: accuracy 141ms happy

# %%
a_sixtyfour = pg.wilcoxon(accuracy_141ms_happy, accuracy_141ms_sad, tail='two-sided').round(4)
a_sixtyfive = pg.wilcoxon(accuracy_141ms_happy, accuracy_141ms_neutral, tail='two-sided').round(4)

# %% [markdown]
# #### remaining Wilcoxon tests for condition: accuracy 141ms sad

# %%
a_sixtysix = pg.wilcoxon(accuracy_141ms_sad, accuracy_141ms_neutral, tail='two-sided').round(4)

# %% [markdown]
# ## Create a DataFrame with the Wilcoxon test results

# %%
a_wilcox = pd.DataFrame(a_two)   
a_wilcox = a_wilcox.append(a_three).append(a_four).append(a_five)
a_wilcox = a_wilcox.append(a_six).append(a_seven).append(a_eight).append(a_nine)
a_wilcox = a_wilcox.append(a_ten).append(a_eleven).append(a_twelve).append(a_thirteen)
a_wilcox = a_wilcox.append(a_fourteen).append(a_fifteen).append(a_sixteen).append(a_seventeen)
a_wilcox = a_wilcox.append(a_eightteen).append(a_nineteen).append(a_twenty).append(a_twentyone)
a_wilcox = a_wilcox.append(a_twentytwo).append(a_twentythree).append(a_twentyfour).append(a_twentyfive)
a_wilcox = a_wilcox.append(a_twentysix).append(a_twentyseven).append(a_twentyeight).append(a_twentynine)
a_wilcox = a_wilcox.append(a_thirty).append(a_thirtyone).append(a_thirtytwo).append(a_thirtythree)
a_wilcox = a_wilcox.append(a_thirtyfour).append(a_thirtyfive).append(a_thirtysix).append(a_thirtyseven)
a_wilcox = a_wilcox.append(a_thirtyeight).append(a_thirtynine).append(a_forty).append(a_fortyone)
a_wilcox = a_wilcox.append(a_fortytwo).append(a_fortythree).append(a_fortyfour).append(a_fortyfive)
a_wilcox = a_wilcox.append(a_fortysix).append(a_fortyseven).append(a_fortyeight).append(a_fortynine)
a_wilcox = a_wilcox.append(a_fifty).append(a_fiftyone).append(a_fiftytwo).append(a_fiftythree)
a_wilcox = a_wilcox.append(a_fiftyfour).append(a_fiftyfive).append(a_fiftysix).append(a_fiftyseven)
a_wilcox = a_wilcox.append(a_fiftyeight).append(a_fiftynine).append(a_sixty).append(a_sixtyone)
a_wilcox = a_wilcox.append(a_sixtytwo).append(a_sixtythree).append(a_sixtyfour).append(a_sixtyfive).append(a_sixtysix)

a_wilcox['Comparison'] = ['8ms happy vs. 8ms sad', '8ms happy vs. 8ms neutral', '8ms happy vs. 16ms happy',
                                    '8ms happy vs. 16ms sad', '8ms happy vs. 16ms neutral',
                                    '8ms happy vs. 25ms happy', '8ms happy vs. 25ms sad',
                                    '8ms happy vs. 25ms neutral', '8ms happy vs. 141ms happy',
                                    '8ms happy vs. 141ms sad', '8ms happy vs. 141ms neutral',
                                    '8ms sad vs. 8ms neutral',
                                    '8ms sad vs. 16ms happy', '8ms sad vs. 16ms sad',
                                    '8ms sad vs. 16ms neutral', '8ms sad vs. 25ms happy',
                                    '8ms sad vs. 25ms sad', '8ms sad vs. 25ms neutral',
                                    '8ms sad vs. 141ms happy', '8ms sad vs. 141ms sad',
                                    '8ms sad vs. 141ms neutral',
                                    '8ms neutral vs. 16ms happy', '8ms neutral vs. 16ms sad',
                                    '8ms neutral vs. 16ms neutral', '8ms neutral vs. 25ms happy',
                                    '8ms neutral vs. 25ms sad', '8ms neutral vs. 25ms neutral',
                                    '8ms neutral vs. 141ms happy','8ms neutral vs. 141ms sad', 
                                    '8ms neutral vs. 141ms neutral',  '16ms happy vs. 16ms sad',
                                     '16ms happy vs. 16ms neutral', '16ms happy vs. 25ms happy',
                                     '16ms happy vs. 25ms sad', '16ms happy vs. 25ms neutral',
                                     '16ms happy vs. 141ms happy','16ms happy vs. 141ms sad', 
                                     '16ms happy vs. 141ms neutral','16ms sad vs. 16ms neutral',
                                     '16ms sad vs. 25ms happy', '16ms sad vs. 25ms sad',
                                     '16ms sad vs. 25ms neutral', '16ms sad vs. 141ms happy',
                                     '16ms sad vs. 141ms sad', '16ms sad vs. 141ms neutral',
                                     '16ms neutral vs. 25ms happy', '16ms neutral vs. 25ms sad',
                                     '16ms neutral vs. 25ms neutral', '16ms neutral vs. 141ms happy',
                                     '16ms neutral vs. 141ms sad', '16ms neutral vs. 141ms neutral',
                                     '25ms happy vs. 25ms sad', '25ms happy vs. 25ms neutral',
                                     '25ms happy vs. 141ms happy', '25ms happy vs. 141ms sad',
                                     '25ms happy vs. 141ms neutral', '25ms sad vs. 25ms neutral',
                                     '25ms sad vs. 141ms happy', '25ms sad vs. 141ms neutral',
                                     '25ms neutral vs. 141ms happy', '25ms neutral vs. 141ms sad',
                                     '25ms neutral vs. 141ms neutral', '141ms happy vs. 141ms sad',
                                     '141ms happy vs. 141ms neutral', '141ms sad vs. 141ms neutral']

# %%
#bon =[(0.05/4),(0.05/4),(0.05/4),(0.05/4)]
#bon = [round(i, 4) for i in bon] #round values
#wilcox['Bonferroni'] = bon

# %%
a_desc_stat.to_csv('C:/Users/Sara Halmans/Documents/Sara/Studium Lübeck/Praktikum Aachen/EEG_fMRT_Depressionsstudie/Datenanalyse Pilotstudie/Second Level Statistics/Descriptive_Accuracy.csv',sep =';', index = True)
a_normality.to_csv('C:/Users/Sara Halmans/Documents/Sara/Studium Lübeck/Praktikum Aachen/EEG_fMRT_Depressionsstudie/Datenanalyse Pilotstudie/Second Level Statistics/Shapiro_Test_Accuracy.csv',sep =';', index = True)
a_homosc.to_csv('C:/Users/Sara Halmans/Documents/Sara/Studium Lübeck/Praktikum Aachen/EEG_fMRT_Depressionsstudie/Datenanalyse Pilotstudie/Second Level Statistics/Homoscedasticity_Accuracy.csv',sep =';', index = True)
a_anova.to_csv('C:/Users/Sara Halmans/Documents/Sara/Studium Lübeck/Praktikum Aachen/EEG_fMRT_Depressionsstudie/Datenanalyse Pilotstudie/Second Level Statistics/Anova_Accuracy.csv',sep =';', index = True)
a_wilcox.to_csv('C:/Users/Sara Halmans/Documents/Sara/Studium Lübeck/Praktikum Aachen/EEG_fMRT_Depressionsstudie/Datenanalyse Pilotstudie/Second Level Statistics/Wilcox_Test_Accuracy.csv',sep =';', index = True)
a_Ttest.to_csv('C:/Users/Sara Halmans/Documents/Sara/Studium Lübeck/Praktikum Aachen/EEG_fMRT_Depressionsstudie/Datenanalyse Pilotstudie/Second Level Statistics/Ttest_Accuracy.csv',sep =';', index = True)

# %% [markdown]
# ## Some theorethical background:
# ***
# #### Before we calculate:  `Testing statistical premises`
#
# Statistical procedures can be classfied into either [`parametric`](https://en.wikipedia.org/wiki/Parametric_statistics) or `non parametric` prcedures, which require different necessary preconditions to be met in order to show consistent/robust results.
# Generally people assume that their data follows a gaussian distribution, which allows for parametric tests to be run.
# Nevertheless it is essential to first test the distribution of your data to decide if the assumption of normally distributed data holds, if this is not the case we would have to switch to non parametric tests.
#
# © Peer Herholz https://github.com/PeerHerholz/brainhack2020_marburg_showcases
#
# ***
# #### Check Distributions
#
# data normal distrubited? test pairwise with t-test
#
# data not normal distributed? test pairwise with wolcoxon rank sum test
#
# ***
# #### ANOVA
# The classic ANOVA is very powerful when the groups are normally distributed and have equal variances. However, when the groups have unequal variances, it is best to use the Welch ANOVA `(pingouin.welch_anova()` that better controls for type I error (Liu 2015).
#
# Is used to analyze the differences among means in a sample.  ANOVA provides a statistical test of whether two or more population means are equal, and therefore generalizes the t-test beyond two means.
#
# ***
# #### Testing for homoscedasticity
#
# "In statistics, a sequence or a vector of random variables is homoscedastic /ˌhoʊmoʊskəˈdæstɪk/ if all random variables in the sequence or vector have the same finite variance." - Wikipedia
#
# returns:
#
# equal_var : boolean True if data have equal variance.
#
# p : float P-value.
#
# Note: This function first tests if the data are normally distributed using the Shapiro-Wilk test. If yes, then the homogeneity of variances is measured using the Bartlett test. If the data are not normally distributed, the Levene test, which is less sensitive to departure from normality, is used.
#
# © Peer Herholz https://github.com/PeerHerholz/brainhack2020_marburg_showcases
#
# ***
# #### Testing for normality
# "`Shapiro Wilk normality  test`" https://pingouin-stats.org/generated/pingouin.normality.html#pingouin.normality)
#
# Standard procedure for testing `normal distribution` tests if the `distribution` of your data `deviates significantly` from a `normal distribution`.
# The function we're using returns the following information:
#
# - W  : Test statistic
#
# - p : float
#     P-value
#
# - normal : boolean
#     True if data comes from a normal distribution.
#
# © Peer Herholz https://github.com/PeerHerholz/brainhack2020_marburg_showcases
# ***
# ### Non parametric tests:
#
#
# Unlike the parametric test these do not require the assumption of normal distributions.
#
# "`Mann-Whitney U Test`" (= Wilcoxon rank-sum test). It is the non-parametric version of the independent T-test.
# Mwu tests the hypothesis that data in x and y are samples from continuous distributions with equal medians. The test assumes that x and y are independent. This test corrects for ties and by default uses a continuity correction." - [mwu-function](https://pingouin-stats.org/generated/pingouin.mwu.html#pingouin.mwu)
#
# Test summary
#
# - 'W-val' : W-value
# - 'p-val' : p-value
# - 'RBC'   : matched pairs rank-biserial correlation (effect size)
# - 'CLES'  : common language effect size
#
# © Peer Herholz https://github.com/PeerHerholz/brainhack2020_marburg_showcases
# ***
# #### Wilcoxon signed-rank test
#
# "`Wilcoxon signed-rank test`" is the non-parametric version of the paired T-test.
#
# The Wilcoxon signed-rank test tests the null hypothesis that two related paired samples come from the same distribution. A continuity correction is applied by default." - [wilcoxon - func](https://pingouin-stats.org/generated/pingouin.wilcoxon.html#pingouin.wilcoxon)
# Note that a listwise deletion of missing values is automatically applied.
#
# ***
# #### Kruskal-Wallis
# `The Kruskal-Wallis H-test` tests the null hypothesis that the population median of all of the groups are equal. It is a non-parametric version of ANOVA. The test works on 2 or more independent samples, which may have different sizes.
# Due to the assumption that H has a chi square distribution, the number of samples in each group must not be too small. A typical rule is that each sample must have at least 5 measurements.
#
# NaN values are automatically removed.
#
#
# ***
# ### Parametric tests:
# `paired T-Test`tests
